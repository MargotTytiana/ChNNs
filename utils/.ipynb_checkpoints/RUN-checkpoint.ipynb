# %%
# !python logger.py
# Out:
# 2025-09-14 20:57:04 | INFO     | chaotic_sr | Experiment logger initialized: test_experiment
# 2025-09-14 20:57:04 | INFO     | chaotic_sr | Log directory: logs/test_experiment
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System information logged
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System platform: Linux-4.18.0-553.74.1.el8_10.x86_64-x86_64-with-glibc2.28
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System python_version: 3.12.10
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System cpu_count: 256
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System memory_total: 503.18 GB
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System torch_version: 2.7.1+cu126
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System cuda_available: True
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System cuda_device_count: 1
# 2025-09-14 20:57:06 | INFO     | chaotic_sr | System timestamp: 2025-09-14T20:57:06.467288
# ...

# %%
# !python checkpoint.py
# Out:
# Testing CheckpointManager...
# CheckpointManager initialized for experiment: test_experiment
# Checkpoint directory: test_checkpoints/test_experiment
# New best checkpoint saved! val_loss: 0.6000
# Checkpoint saved: test_checkpoints/test_experiment/checkpoint_epoch_0000_20250914_205834.pt
# Saved checkpoint for epoch 0
# New best checkpoint saved! val_loss: 0.5600
# Checkpoint saved: test_checkpoints/test_experiment/checkpoint_epoch_0001_20250914_205834.pt
# Saved checkpoint for epoch 1
# New best checkpoint saved! val_loss: 0.5200
# Checkpoint saved: test_checkpoints/test_experiment/checkpoint_epoch_0002_20250914_205834.pt
# Saved checkpoint for epoch 2
# New best checkpoint saved! val_loss: 0.4800
# Removed old checkpoint: test_checkpoints/test_experiment/checkpoint_epoch_0000_20250914_205834.pt
# Checkpoint saved: test_checkpoints/test_experiment/checkpoint_epoch_0003_20250914_205834.pt
# Saved checkpoint for epoch 3
# New best checkpoint saved! val_loss: 0.4400
# ...

# %%
# !python numerical_stability.py
# Out:
# Testing Numerical Stability Tools...
# Array dtype: float64
# Condition number: 14.93
# Well conditioned: True
# Outliers detected: 0 positions
# Memory usage: 0.080 GB
# Array validation: PASS
# Numerical Stability Tools testing completed!

# %%
# !python reproducibility.py
# Out:
# Testing Reproducibility Manager...
# [2025-09-14 21:00:02] [INFO] Setting global random seed to: 42
# [2025-09-14 21:00:02] [INFO] Python random seed set
# [2025-09-14 21:00:02] [INFO] PYTHONHASHSEED set to: 42
# [2025-09-14 21:00:02] [INFO] NumPy random seed set
# [2025-09-14 21:00:02] [INFO] PyTorch CUDA seeds set
# [2025-09-14 21:00:02] [INFO] PyTorch strict reproducibility mode enabled
# [2025-09-14 21:00:02] [INFO] PyTorch seeds set
# [2025-09-14 21:00:02] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2025-09-14 21:00:02] [INFO] Environment information collected
# [2025-09-14 21:00:02] [INFO] Configuring deterministic operations
# [2025-09-14 21:00:02] [INFO] PyTorch deterministic operations configured
# [2025-09-14 21:00:02] [INFO] Starting reproducibility verification
# [2025-09-14 21:00:02] [INFO] Setting global random seed to: 42
# [2025-09-14 21:00:02] [INFO] Python random seed set
# [2025-09-14 21:00:02] [INFO] PYTHONHASHSEED set to: 42
# ...
