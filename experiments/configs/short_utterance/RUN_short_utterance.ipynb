# %% [markdown]
# # 快速测试已有模型

# %%
# !python quick_short_utterance_test.py \
    --model "/scratch/project_2003370/yueyao/Model/experiments/configs/base_chaotic/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260122_131044/checkpoint_epoch_0092.pt" \
    --data /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --model_type chaotic \
    --num_speakers 26 \
    --durations 0.5 1.0 1.5 2.0 2.5 3.0 \
    --num_crops 5 \
    --batch_size 32 \
    --device cpu \
    --output ./short_utterance_results
# Out:
# ...
# QUICK SHORT UTTERANCE TEST
# ...
# Model: /scratch/project_2003370/yueyao/Model/experiments/configs/base_chaotic/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260122_131044/checkpoint_epoch_0092.pt
# Data: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Durations: [0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
# Device: cpu
#
# Loading dataset...
# Loading LibriSpeech dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# /scratch/project_2003370/yueyao/Model/data/dataset_loader.py:324: UserWarning: Dataset validation warnings: ['Dataset must contain at least 2 speakers, found 0']
#   warnings.warn(f"Dataset validation warnings: {validation_result['errors']}")
# ...

# %%
# !python quick_short_utterance_test.py \
    --model "/scratch/project_2003370/yueyao/Model/experiments/configs/base_chaotic/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260122_131044/checkpoint_epoch_0092.pt" \
    --data /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --model_type chaotic \
    --num_speakers 26 \
    --durations 0.5 1.0 1.5 2.0 2.5 3.0 \
    --num_crops 5 \
    --batch_size 32 \
    --device cpu \
    --output ./short_utterance_results
# Out:
# ...
# QUICK SHORT UTTERANCE TEST
# ...
# Model: /scratch/project_2003370/yueyao/Model/experiments/configs/base_chaotic/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260122_131044/checkpoint_epoch_0092.pt
# Data: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Durations: [0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
# Device: cpu
#
# Loading dataset...
# Loading LibriSpeech dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# /scratch/project_2003370/yueyao/Model/data/dataset_loader.py:324: UserWarning: Dataset validation warnings: ['Dataset must contain at least 2 speakers, found 0']
#   warnings.warn(f"Dataset validation warnings: {validation_result['errors']}")
# ...

# %% [markdown]
# # 251 speakers

# %%
# !python quick_short_utterance_test.py \
    --model "/scratch/project_2003370/yueyao/Model/experiments/configs/base_chaotic/full_speaker/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260127_081609/checkpoint_epoch_0098.pt" \
    --data /scratch/project_2003370/yueyao/dataset/train-clean-100/LibriSpeech/train-clean-100 \
    --model_type chaotic \
    --num_speakers 251 \
    --durations 0.5 1.0 1.5 2.0 2.5 3.0 \
    --num_crops 5 \
    --batch_size 32 \
    --device cpu \
    --output ./short_utterance_results
# Out:
# ...
# QUICK SHORT UTTERANCE TEST
# ...
# Model: /scratch/project_2003370/yueyao/Model/experiments/configs/base_chaotic/full_speaker/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260127_081609/checkpoint_epoch_0098.pt
# Data: /scratch/project_2003370/yueyao/dataset/train-clean-100/LibriSpeech/train-clean-100
# Durations: [0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
# Device: cpu
#
# Loading dataset...
# Loading LibriSpeech dataset from: /scratch/project_2003370/yueyao/dataset/train-clean-100/LibriSpeech/train-clean-100
# /scratch/project_2003370/yueyao/Model/data/dataset_loader.py:324: UserWarning: Dataset validation warnings: ['Dataset must contain at least 2 speakers, found 0']
#   warnings.warn(f"Dataset validation warnings: {validation_result['errors']}")
# ...

# %% [markdown]
# # 完整实验流程
#
# 从头训练模型并进行完整对比：

# %%
# !python short_utterance_experiment.py \
    --config short_utterance_config.yaml \
    --output_dir ./outputs/short_utterance_comparison \
    --seed 42
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %%
# !python short_utterance_experiment.py \
    --config short_utterance_config.yaml \
    --output_dir ./outputs/comparison
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %%
# !python test_with_training_eval.py
# Out:
# ...
# TEST WITH TRAINING EVALUATION FUNCTION
# ...
# Project root: /scratch/project_2003370/yueyao/Model
# Experiment dir: /scratch/project_2003370/yueyao/Model/experiments
# Config dir: /scratch/project_2003370/yueyao/Model/experiments/configs/base_chaotic
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# ...
