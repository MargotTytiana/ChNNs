# %% [markdown]
# ## 假设 4：时机不当
#
# ### 4.1 验证思路
#
# 可能模型需要先学习基本模式，之后再施加同步约束。
#
# ### 4.2 实验设计
#
# | 实验 | sync_warmup_epochs | 说明 |
# | --- | --- | --- |
# | H4-a | 20 | 前20轮不用同步损失 |
# | H4-b | 50 | 前50轮不用同步损失 |
# | H4-c | 渐进 | 权重从0线性增加 |

# %%
# H4a
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4a \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4a/experiment_H4a_warmup_20.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %%
# H4b
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4b \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4b/experiment_H4b_warmup_50.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %%
# H4c
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4c \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4c/experiment_H4c_progressive.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %% [raw]
#   synchronization:
#     enabled: true
#     sync_weight: 0.1
#     desync_weight: 0.1
#     margin: 1.0
#     sample_ratio: 0.3
#     distance_type: "euclidean"
#     warmup_epochs: 30       # DELAY: no sync loss for first 20 epochs
#     schedule_mode: "none"  # or "sync_first", "desync_first", "gradual_transition"
#     phase1_epochs: 50

# %%
# H4d
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4d \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4d/experiment_H4d.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %% [raw]
#   synchronization:
#     enabled: true
#     sync_weight: 0.1
#     desync_weight: 0.1
#     margin: 1.0
#     sample_ratio: 0.3
#     distance_type: "euclidean"
#     warmup_epochs: 70       # DELAY: no sync loss for first 20 epochs
#     schedule_mode: "none"  # or "sync_first", "desync_first", "gradual_transition"
#     phase1_epochs: 50

# %%
# H4e
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4e \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4e/experiment_H4e.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %% [raw]
# loss:
#   synchronization:
#     enabled: true
#     sync_weight: 0.1
#     desync_weight: 0.1
#     warmup_epochs: 999  # 设置很大，由动态激活接管
#     dynamic_warmup: true
#     activation_accuracy: 0.7  # 当训练准确率达到70%时激活

# %%
# H4f
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4f \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4f/experiment_H4f.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %% [raw]
# loss:
#   synchronization:
#     enabled: true
#     sync_weight: 0.1
#     desync_weight: 0.1
#     warmup_epochs: 999  # 设置很大，由动态激活接管
#     dynamic_warmup: true
#     activation_accuracy: 0.1  # 当训练准确率达到10%时激活

# %%
# H4g
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4g \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4g/experiment_H4g.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %% [raw]
# loss:
#   synchronization:
#     enabled: true
#     sync_weight: 0.1
#     desync_weight: 0.1
#     warmup_epochs: 999  # 设置很大，由动态激活接管
#     dynamic_warmup: true
#     activation_accuracy: 0.2  # 当训练准确率达到20%时激活

# %%
# H4j
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4j \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4j/experiment_H4j.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %% [raw]
# loss:
#   synchronization:
#     enabled: true
#     sync_weight: 0.1
#     desync_weight: 0.1
#     warmup_epochs: 999  # 设置很大，由动态激活接管
#     dynamic_warmup: true
#     activation_accuracy: 0.3  # 当训练准确率达到30%时激活

# %%
# H4h
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4h \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4h/experiment_H4h.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %% [raw]
# loss:
#   synchronization:
#     enabled: true
#     sync_weight: 0.1
#     desync_weight: 0.1
#     warmup_epochs: 999  # 设置很大，由动态激活接管
#     dynamic_warmup: true
#     activation_accuracy: 0.5  # 当训练准确率达到50%时激活

# %%
# H4i
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4i \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/H4/H4i/experiment_H4i.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...
