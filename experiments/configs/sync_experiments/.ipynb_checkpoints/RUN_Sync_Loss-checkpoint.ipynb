# %%
# 实验 A：完整模型
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/experiment_A_full_sync.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: True
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# 实验 B：无同步损失
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/experiment_B_no_sync.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: False
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# 实验 C：仅同步项
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/experiment_C_sync_only.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: True
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# 实验 D：纯交叉熵基线
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/experiment_D_baseline.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: False
#   - Sync: False
#   - Adversarial: False
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# 实验 E：Desync Only, No Sync
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/experiment_E_desync_only.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: True
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# 实验 F：No Adversarial, With Sync
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/experiment_F_no_adversarial.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: True
#   - Adversarial: False
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# 假设 2：权重过大
# 2.1 验证思路
# 如果 sync_weight=0.1 太大，降低权重应该改善性能。
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/experiment_H2a_small_weight.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: True
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# 假设 2：权重过大
# 2.1 验证思路
# 如果 sync_weight=0.1 太大，降低权重应该改善性能。
# !python run_training.py \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/experiment_H2b_tiny_weight.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: cosine
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: True
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...
