# %%
# !python collect_section51_stats.py
# Out:
# ...
# SECTION 5.1 STATISTICS COLLECTION
# Generated: 2026-01-12 11:27:21
# ...
#
# ----------------------------------------------------------------------
# 1. DATASET STATISTICS
# ----------------------------------------------------------------------
#
# Scanning main dataset: /scratch/project_2003370/yueyao/dataset/train-clean-100/LibriSpeech/train-clean-100
#   ✓ Speakers: 100
#   ✓ Total utterances: ~12,574
#
# Scanning ablation dataset: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
#   ✓ Speakers: 26
#   ✓ Total utterances: ~1,089
#
# ...
# TABLE 5.1: Dataset Statistics
# ...
# Property                       Main Experiments     Ablation Studies
# ----------------------------------------------------------------------
# Dataset                        LibriSpeech          LibriSpeech
# Subset                         train-clean-100      dev-clean-2
# Number of speakers             100                  26
# Total utterances               ~12,574              ~1,089
# ...
