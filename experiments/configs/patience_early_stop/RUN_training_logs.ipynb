# %%
# !python analyze_training_logs.py --log_file /scratch/project_2003370/yueyao/Model/experiments/configs/sync_experiments/E/experiments/chaotic_lorenz_full_chaotic_run_0/experiment_state.json
# Out:
# Loading training history...
# [DEBUG] JSON top-level keys: ['epoch', 'step', 'best_metric', 'best_epoch', 'train_losses', 'val_metrics', 'start_time', 'end_time', 'status']
# [DEBUG] Parsed data - train_losses: 100, val_losses: 100, val_accuracies: 100
# Loaded 100 epochs of training data
#
# Running analysis...
#
# Convergence Analysis:
#   Best accuracy: 0.9663 at epoch 86
#   Epochs to 90% of best: 58
#   Epochs to 95% of best: 58
#
# Simulating early stopping with different patience values...
#
# Recommended patience: 19
# Report saved to: analysis_output/analysis_report.txt
#
# ...
# TRAINING LOG ANALYSIS REPORT
# ...
#
# 1. TRAINING OVERVIEW
# ----------------------------------------
#    Total epochs trained: 100
#    Final train loss: 0.317287
#    Final val loss: 0.177131
#    Best val accuracy: 0.9663 (Epoch 86)
#
# 2. PATIENCE SIMULATION RESULTS
# ----------------------------------------
#    Patience   Stop Epoch   Best Value   Missed       Saved
# ...

# %%
# !python analyze_training_logs.py --log_file /scratch/project_2003370/yueyao/Model/experiments/configs/patience_early_stop/20/experiments/chaotic_lorenz_full_chaotic_run_0/experiment_state.json
# Out:
# Loading training history...
# [DEBUG] JSON top-level keys: ['epoch', 'step', 'best_metric', 'best_epoch', 'train_losses', 'val_metrics', 'start_time', 'end_time', 'status']
# [DEBUG] Parsed data - train_losses: 98, val_losses: 98, val_accuracies: 98
# Loaded 98 epochs of training data
#
# Running analysis...
#
# Convergence Analysis:
#   Best accuracy: 0.9888 at epoch 77
#   Epochs to 90% of best: 50
#   Epochs to 95% of best: 60
#
# Simulating early stopping with different patience values...
#
# Recommended patience: 26
# Report saved to: analysis_output/analysis_report.txt
#
# ...
# TRAINING LOG ANALYSIS REPORT
# ...
#
# 1. TRAINING OVERVIEW
# ----------------------------------------
#    Total epochs trained: 98
#    Final train loss: 0.083273
#    Final val loss: 0.060935
#    Best val accuracy: 0.9888 (Epoch 77)
#
# 2. PATIENCE SIMULATION RESULTS
# ----------------------------------------
#    Patience   Stop Epoch   Best Value   Missed       Saved
# ...

# %%
# !python analyze_training_logs.py --log_file /scratch/project_2003370/yueyao/Model/experiments/configs/patience_early_stop/30/experiments/chaotic_lorenz_full_chaotic_run_0/experiment_state.json
# Out:
# Loading training history...
# [DEBUG] JSON top-level keys: ['epoch', 'step', 'best_metric', 'best_epoch', 'train_losses', 'val_metrics', 'start_time', 'end_time', 'status']
# [DEBUG] Parsed data - train_losses: 100, val_losses: 100, val_accuracies: 100
# Loaded 100 epochs of training data
#
# Running analysis...
#
# Convergence Analysis:
#   Best accuracy: 0.9888 at epoch 77
#   Epochs to 90% of best: 50
#   Epochs to 95% of best: 60
#
# Simulating early stopping with different patience values...
#
# Recommended patience: 28
# Report saved to: analysis_output/analysis_report.txt
#
# ...
# TRAINING LOG ANALYSIS REPORT
# ...
#
# 1. TRAINING OVERVIEW
# ----------------------------------------
#    Total epochs trained: 100
#    Final train loss: 0.076690
#    Final val loss: 0.063050
#    Best val accuracy: 0.9888 (Epoch 77)
#
# 2. PATIENCE SIMULATION RESULTS
# ----------------------------------------
#    Patience   Stop Epoch   Best Value   Missed       Saved
# ...

# %%
# !python analyze_training_logs.py --log_file /scratch/project_2003370/yueyao/Model/experiments/configs/patience_early_stop/19/experiments/chaotic_lorenz_full_chaotic_run_0/experiment_state.json
# Out:
# Loading training history...
# [DEBUG] JSON top-level keys: ['epoch', 'step', 'best_metric', 'best_epoch', 'train_losses', 'val_metrics', 'start_time', 'end_time', 'status']
# [DEBUG] Parsed data - train_losses: 97, val_losses: 97, val_accuracies: 97
# Loaded 97 epochs of training data
#
# Running analysis...
#
# Convergence Analysis:
#   Best accuracy: 0.9888 at epoch 77
#   Epochs to 90% of best: 50
#   Epochs to 95% of best: 60
#
# Simulating early stopping with different patience values...
#
# Recommended patience: 25
# Report saved to: analysis_output/analysis_report.txt
#
# ...
# TRAINING LOG ANALYSIS REPORT
# ...
#
# 1. TRAINING OVERVIEW
# ----------------------------------------
#    Total epochs trained: 97
#    Final train loss: 0.085544
#    Final val loss: 0.059250
#    Best val accuracy: 0.9888 (Epoch 77)
#
# 2. PATIENCE SIMULATION RESULTS
# ----------------------------------------
#    Patience   Stop Epoch   Best Value   Missed       Saved
# ...

# %%
# !python analyze_training_logs.py --log_file /scratch/project_2003370/yueyao/Model/experiments/configs/patience_early_stop/50/experiments/chaotic_lorenz_full_chaotic_run_0/experiment_state.json
# Out:
# Loading training history...
# [DEBUG] JSON top-level keys: ['epoch', 'step', 'best_metric', 'best_epoch', 'train_losses', 'val_metrics', 'start_time', 'end_time', 'status']
# [DEBUG] Parsed data - train_losses: 100, val_losses: 100, val_accuracies: 100
# Loaded 100 epochs of training data
#
# Running analysis...
#
# Convergence Analysis:
#   Best accuracy: 0.9888 at epoch 77
#   Epochs to 90% of best: 50
#   Epochs to 95% of best: 60
#
# Simulating early stopping with different patience values...
#
# Recommended patience: 28
# Report saved to: analysis_output/analysis_report.txt
#
# ...
# TRAINING LOG ANALYSIS REPORT
# ...
#
# 1. TRAINING OVERVIEW
# ----------------------------------------
#    Total epochs trained: 100
#    Final train loss: 0.076690
#    Final val loss: 0.063050
#    Best val accuracy: 0.9888 (Epoch 77)
#
# 2. PATIENCE SIMULATION RESULTS
# ----------------------------------------
#    Patience   Stop Epoch   Best Value   Missed       Saved
# ...
