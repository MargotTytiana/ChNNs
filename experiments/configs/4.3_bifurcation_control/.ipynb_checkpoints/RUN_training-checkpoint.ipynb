# %% [markdown]
# # IMPORTANT!

# %% [markdown]
# ### Bifurcation Control
#
# 改config bifurcation_control: "true"

# %%
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/chaotic_config_on.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#   ✓ Dataset loader imported successfully
# ✓ Data package initialized (circular import free)
# All required modules imported successfully!
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Environment information collected
# [2026-02-23 09:26:20] [INFO] Configuring deterministic operations
# [2026-02-23 09:26:20] [INFO] PyTorch deterministic operations configured
# [2026-02-23 09:26:20] [INFO] Starting reproducibility verification
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Operation 1 is reproducible
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Operation 2 is reproducible
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Operation 3 is reproducible
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Operation 4 is reproducible
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:20] [INFO] Python random seed set
# [2026-02-23 09:26:20] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:20] [INFO] NumPy random seed set
# [2026-02-23 09:26:20] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:20] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:20] [INFO] PyTorch seeds set
# [2026-02-23 09:26:20] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:20] [INFO] Operation 5 is reproducible
# [2026-02-23 09:26:20] [SUCCESS] All operations are reproducible
#
# ============================================================
# REPRODUCIBILITY SUMMARY
# ============================================================
# Seed: 42
# Strict Mode: True
# Environment Hash: 6650ae7c34ebf012
# Python Version: 3.12.10
#
# Available Libraries:
#   numpy: 1.26.4
#   torch: 2.7.1+cu126
#   cuda_version: 12.6
#   cudnn_version: 91002
#   librosa: 0.11.0
#   soundfile: 0.13.1
#
# Environment Variables:
#   PYTHONHASHSEED: 42
#   CUDA_VISIBLE_DEVICES: MIG-24ae1daa-9c0a-5c0f-bbc1-bacbeac9256d
#   OMP_NUM_THREADS: not_set
#   MKL_NUM_THREADS: not_set
# ============================================================
# 2026-02-23 09:26:20,777 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================
# 2026-02-23 09:26:20,797 - chaotic_trainer - INFO - CHAOTIC NEURAL NETWORKS TRAINING
# INFO:chaotic_trainer:CHAOTIC NEURAL NETWORKS TRAINING
# 2026-02-23 09:26:20,798 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================
# 2026-02-23 09:26:20,798 - chaotic_trainer - INFO - Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On
# INFO:chaotic_trainer:Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On
# 2026-02-23 09:26:20,798 - chaotic_trainer - INFO - Configuration: {
#   "_nested": {
#     "experiment": {
#       "name": "bifurcation_on"
#     },
#     "data": {
#       "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#       "train_split": 0.7,
#       "val_split": 0.15,
#       "test_split": 0.15,
#       "num_workers": 4,
#       "pin_memory": true,
#       "prefetch_factor": 2,
#       "cache_features": false,
#       "cache_dir": "./cache"
#     },
#     "audio": {
#       "sample_rate": 16000,
#       "max_audio_length": 3.0,
#       "min_audio_length": 0.5,
#       "frame_length": 400,
#       "hop_length": 160,
#       "normalize": true,
#       "remove_silence": false,
#       "augmentation": {
#         "enabled": false,
#         "noise_injection": 0.005,
#         "time_stretch_range": [
#           0.9,
#           1.1
#         ],
#         "pitch_shift_range": [
#           -2,
#           2
#         ]
#       }
#     },
#     "model": {
#       "type": "full_chaotic",
#       "num_speakers": 251,
#       "phase_space": {
#         "embedding_dim": 10,
#         "delay_method": "autocorr",
#         "dimension_method": "false_neighbors",
#         "fixed_delay": 10
#       },
#       "chaotic_features": {
#         "mlsa": {
#           "scales": 5,
#           "max_lyapunov_steps": 1000
#         },
#         "rqa": {
#           "radius_ratio": 0.1,
#           "min_line_length": 2
#         }
#       },
#       "chaotic_embedding": {
#         "system_type": "lorenz",
#         "evolution_time": 0.5,
#         "time_step": 0.01,
#         "coupling_strength": 1.0,
#         "noise_level": 0.001,
#         "lorenz": {
#           "sigma": 10.0,
#           "rho": 28.0,
#           "beta": 2.6667
#         },
#         "rossler": {
#           "a": 0.2,
#           "b": 0.2,
#           "c": 5.7
#         }
#       },
#       "attractor_pooling": {
#         "type": "comprehensive",
#         "correlation_dimension": {
#           "num_radii": 50
#         }
#       },
#       "speaker_embedding": {
#         "dim": 256,
#         "hidden_dims": [
#           512,
#           256,
#           128
#         ],
#         "dropout_rate": 0.3,
#         "use_batch_norm": true
#       },
#       "classifier": {
#         "type": "cosine",
#         "temperature": 30.0,
#         "margin": 0.35,
#         "plda": {
#           "latent_dim": 128,
#           "use_length_norm": true
#         }
#       }
#     },
#     "optional_modules": {
#       "bifurcation_control": {
#         "enabled": true,
#         "num_regimes": 4,
#         "hidden_dim": 32,
#         "control_strength": 0.5,
#         "learnable_boundaries": true
#       },
#       "differentiable_features": {
#         "enabled": true,
#         "lyapunov_dim": 8,
#         "rqa_dim": 6,
#         "additional_stats": true
#       }
#     },
#     "loss": {
#       "classification": {
#         "type": "cross_entropy",
#         "label_smoothing": 0.0
#       },
#       "stability": {
#         "enabled": true,
#         "weight": 0.1,
#         "target_lyapunov_range": [
#           0.1,
#           2.0
#         ],
#         "trajectory_bound": 50.0,
#         "collapse_threshold": 0.1,
#         "diversity_weight": 0.05
#       },
#       "synchronization": {
#         "enabled": false,
#         "sync_weight": 0.1,
#         "desync_weight": 0.1,
#         "margin": 1.0,
#         "sample_ratio": 1,
#         "distance_type": "euclidean"
#       },
#       "adversarial": {
#         "enabled": false,
#         "warmup_epochs": 5,
#         "perturbation_scale": 0.1,
#         "parameter_noise": true,
#         "trajectory_noise": true,
#         "weight": 0.3
#       }
#     },
#     "training": {
#       "batch_size": 32,
#       "num_epochs": 100,
#       "gradient_clipping": 1.0,
#       "gradient_accumulation_steps": 1,
#       "mixed_precision": false,
#       "optimizer": {
#         "type": "adamw",
#         "learning_rate": 0.0005,
#         "weight_decay": 0.0001,
#         "betas": [
#           0.9,
#           0.999
#         ],
#         "eps": 1e-08,
#         "momentum": 0.9,
#         "nesterov": true
#       },
#       "scheduler": {
#         "type": "cosine",
#         "T_max": 100,
#         "eta_min": 1e-06,
#         "step_size": 30,
#         "gamma": 0.1,
#         "patience": 10,
#         "factor": 0.5,
#         "min_lr": 1e-07,
#         "warmup_epochs": 5,
#         "warmup_start_lr": 1e-06
#       },
#       "early_stopping": {
#         "enabled": true,
#         "patience": 30,
#         "min_delta": 0.001,
#         "monitor": "val_accuracy",
#         "mode": "max"
#       },
#       "checkpoint": {
#         "save_best_only": true,
#         "save_frequency": 10,
#         "max_to_keep": 3
#       }
#     },
#     "evaluation": {
#       "metrics": [
#         "accuracy",
#         "top5_accuracy",
#         "eer",
#         "dcf"
#       ],
#       "eval_frequency": 1,
#       "visualization": {
#         "enabled": true,
#         "plot_confusion_matrix": true,
#         "plot_embeddings": true,
#         "plot_attractors": true
#       }
#     },
#     "logging": {
#       "level": "INFO",
#       "tensorboard": {
#         "enabled": true,
#         "log_dir": "./runs"
#       },
#       "wandb": {
#         "enabled": false,
#         "project": "chaotic-speaker-recognition",
#         "entity": null
#       },
#       "log_frequency": 50
#     },
#     "output": {
#       "base_dir": "./experiments/outputs",
#       "save_predictions": true,
#       "save_embeddings": true,
#       "save_analysis": true
#     },
#     "hardware": {
#       "device": "auto",
#       "seed": 42,
#       "deterministic": false,
#       "benchmark": true
#     },
#     "presets": {
#       "fast_debug": {
#         "training": {
#           "batch_size": 8,
#           "num_epochs": 5
#         },
#         "model": {
#           "speaker_embedding": {
#             "hidden_dims": [
#               128,
#               64
#             ]
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": false
#           },
#           "synchronization": {
#             "enabled": false
#           }
#         }
#       },
#       "baseline": {
#         "model": {
#           "classifier": {
#             "type": "linear"
#           }
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": false
#           }
#         }
#       },
#       "high_performance": {
#         "model": {
#           "speaker_embedding": {
#             "dim": 512,
#             "hidden_dims": [
#               1024,
#               512,
#               256
#             ]
#           },
#           "classifier": {
#             "type": "cosine"
#           }
#         },
#         "training": {
#           "num_epochs": 200,
#           "batch_size": 64
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": true,
#             "warmup_epochs": 10
#           }
#         }
#       },
#       "robust": {
#         "model": {
#           "chaotic_embedding": {
#             "noise_level": 0.01
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": true,
#             "perturbation_scale": 0.15,
#             "warmup_epochs": 3
#           }
#         },
#         "audio": {
#           "augmentation": {
#             "enabled": true,
#             "noise_injection": 0.01
#           }
#         }
#       }
#     }
#   },
#   "num_speakers": 251,
#   "model_type": "full_chaotic",
#   "embedding_dim": 10,
#   "delay_method": "autocorr",
#   "mlsa_scales": 5,
#   "rqa_radius_ratio": 0.1,
#   "chaotic_system": "lorenz",
#   "evolution_time": 0.5,
#   "time_step": 0.01,
#   "coupling_strength": 1.0,
#   "noise_level": 0.001,
#   "pooling_type": "comprehensive",
#   "speaker_embedding_dim": 256,
#   "embedding_hidden_dims": [
#     512,
#     256,
#     128
#   ],
#   "classifier_type": "cosine",
#   "temperature": 30.0,
#   "margin": 0.35,
#   "batch_size": 32,
#   "num_epochs": 100,
#   "learning_rate": 0.0005,
#   "weight_decay": 0.0001,
#   "gradient_clipping": 1.0,
#   "optimizer": {
#     "type": "adamw",
#     "params": {
#       "betas": [
#         0.9,
#         0.999
#       ],
#       "eps": 1e-08,
#       "weight_decay": 0.0001
#     }
#   },
#   "scheduler": {
#     "type": "cosine",
#     "params": {
#       "T_max": 100,
#       "eta_min": 1e-06
#     }
#   },
#   "early_stopping": {
#     "patience": 30
#   },
#   "sample_rate": 16000,
#   "max_audio_length": 3.0,
#   "frame_length": 400,
#   "hop_length": 160,
#   "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#   "device": "auto",
#   "seed": 42,
#   "loss_config": {
#     "classification": {
#       "type": "cross_entropy",
#       "label_smoothing": 0.0
#     },
#     "stability": {
#       "enabled": true,
#       "weight": 0.1,
#       "target_lyapunov_range": [
#         0.1,
#         2.0
#       ],
#       "trajectory_bound": 50.0,
#       "collapse_threshold": 0.1,
#       "diversity_weight": 0.05
#     },
#     "synchronization": {
#       "enabled": false,
#       "sync_weight": 0.1,
#       "desync_weight": 0.1,
#       "margin": 1.0,
#       "sample_ratio": 1,
#       "distance_type": "euclidean"
#     },
#     "adversarial": {
#       "enabled": false,
#       "warmup_epochs": 5,
#       "perturbation_scale": 0.1,
#       "parameter_noise": true,
#       "trajectory_noise": true,
#       "weight": 0.3
#     }
#   },
#   "optional_modules": {
#     "bifurcation_control": {
#       "enabled": true,
#       "num_regimes": 4,
#       "hidden_dim": 32,
#       "control_strength": 0.5,
#       "learnable_boundaries": true
#     },
#     "differentiable_features": {
#       "enabled": true,
#       "lyapunov_dim": 8,
#       "rqa_dim": 6,
#       "additional_stats": true
#     }
#   },
#   "epochs": 100,
#   "optimize_parameters": true
# }
# INFO:chaotic_trainer:Configuration: {
#   "_nested": {
#     "experiment": {
#       "name": "bifurcation_on"
#     },
#     "data": {
#       "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#       "train_split": 0.7,
#       "val_split": 0.15,
#       "test_split": 0.15,
#       "num_workers": 4,
#       "pin_memory": true,
#       "prefetch_factor": 2,
#       "cache_features": false,
#       "cache_dir": "./cache"
#     },
#     "audio": {
#       "sample_rate": 16000,
#       "max_audio_length": 3.0,
#       "min_audio_length": 0.5,
#       "frame_length": 400,
#       "hop_length": 160,
#       "normalize": true,
#       "remove_silence": false,
#       "augmentation": {
#         "enabled": false,
#         "noise_injection": 0.005,
#         "time_stretch_range": [
#           0.9,
#           1.1
#         ],
#         "pitch_shift_range": [
#           -2,
#           2
#         ]
#       }
#     },
#     "model": {
#       "type": "full_chaotic",
#       "num_speakers": 251,
#       "phase_space": {
#         "embedding_dim": 10,
#         "delay_method": "autocorr",
#         "dimension_method": "false_neighbors",
#         "fixed_delay": 10
#       },
#       "chaotic_features": {
#         "mlsa": {
#           "scales": 5,
#           "max_lyapunov_steps": 1000
#         },
#         "rqa": {
#           "radius_ratio": 0.1,
#           "min_line_length": 2
#         }
#       },
#       "chaotic_embedding": {
#         "system_type": "lorenz",
#         "evolution_time": 0.5,
#         "time_step": 0.01,
#         "coupling_strength": 1.0,
#         "noise_level": 0.001,
#         "lorenz": {
#           "sigma": 10.0,
#           "rho": 28.0,
#           "beta": 2.6667
#         },
#         "rossler": {
#           "a": 0.2,
#           "b": 0.2,
#           "c": 5.7
#         }
#       },
#       "attractor_pooling": {
#         "type": "comprehensive",
#         "correlation_dimension": {
#           "num_radii": 50
#         }
#       },
#       "speaker_embedding": {
#         "dim": 256,
#         "hidden_dims": [
#           512,
#           256,
#           128
#         ],
#         "dropout_rate": 0.3,
#         "use_batch_norm": true
#       },
#       "classifier": {
#         "type": "cosine",
#         "temperature": 30.0,
#         "margin": 0.35,
#         "plda": {
#           "latent_dim": 128,
#           "use_length_norm": true
#         }
#       }
#     },
#     "optional_modules": {
#       "bifurcation_control": {
#         "enabled": true,
#         "num_regimes": 4,
#         "hidden_dim": 32,
#         "control_strength": 0.5,
#         "learnable_boundaries": true
#       },
#       "differentiable_features": {
#         "enabled": true,
#         "lyapunov_dim": 8,
#         "rqa_dim": 6,
#         "additional_stats": true
#       }
#     },
#     "loss": {
#       "classification": {
#         "type": "cross_entropy",
#         "label_smoothing": 0.0
#       },
#       "stability": {
#         "enabled": true,
#         "weight": 0.1,
#         "target_lyapunov_range": [
#           0.1,
#           2.0
#         ],
#         "trajectory_bound": 50.0,
#         "collapse_threshold": 0.1,
#         "diversity_weight": 0.05
#       },
#       "synchronization": {
#         "enabled": false,
#         "sync_weight": 0.1,
#         "desync_weight": 0.1,
#         "margin": 1.0,
#         "sample_ratio": 1,
#         "distance_type": "euclidean"
#       },
#       "adversarial": {
#         "enabled": false,
#         "warmup_epochs": 5,
#         "perturbation_scale": 0.1,
#         "parameter_noise": true,
#         "trajectory_noise": true,
#         "weight": 0.3
#       }
#     },
#     "training": {
#       "batch_size": 32,
#       "num_epochs": 100,
#       "gradient_clipping": 1.0,
#       "gradient_accumulation_steps": 1,
#       "mixed_precision": false,
#       "optimizer": {
#         "type": "adamw",
#         "learning_rate": 0.0005,
#         "weight_decay": 0.0001,
#         "betas": [
#           0.9,
#           0.999
#         ],
#         "eps": 1e-08,
#         "momentum": 0.9,
#         "nesterov": true
#       },
#       "scheduler": {
#         "type": "cosine",
#         "T_max": 100,
#         "eta_min": 1e-06,
#         "step_size": 30,
#         "gamma": 0.1,
#         "patience": 10,
#         "factor": 0.5,
#         "min_lr": 1e-07,
#         "warmup_epochs": 5,
#         "warmup_start_lr": 1e-06
#       },
#       "early_stopping": {
#         "enabled": true,
#         "patience": 30,
#         "min_delta": 0.001,
#         "monitor": "val_accuracy",
#         "mode": "max"
#       },
#       "checkpoint": {
#         "save_best_only": true,
#         "save_frequency": 10,
#         "max_to_keep": 3
#       }
#     },
#     "evaluation": {
#       "metrics": [
#         "accuracy",
#         "top5_accuracy",
#         "eer",
#         "dcf"
#       ],
#       "eval_frequency": 1,
#       "visualization": {
#         "enabled": true,
#         "plot_confusion_matrix": true,
#         "plot_embeddings": true,
#         "plot_attractors": true
#       }
#     },
#     "logging": {
#       "level": "INFO",
#       "tensorboard": {
#         "enabled": true,
#         "log_dir": "./runs"
#       },
#       "wandb": {
#         "enabled": false,
#         "project": "chaotic-speaker-recognition",
#         "entity": null
#       },
#       "log_frequency": 50
#     },
#     "output": {
#       "base_dir": "./experiments/outputs",
#       "save_predictions": true,
#       "save_embeddings": true,
#       "save_analysis": true
#     },
#     "hardware": {
#       "device": "auto",
#       "seed": 42,
#       "deterministic": false,
#       "benchmark": true
#     },
#     "presets": {
#       "fast_debug": {
#         "training": {
#           "batch_size": 8,
#           "num_epochs": 5
#         },
#         "model": {
#           "speaker_embedding": {
#             "hidden_dims": [
#               128,
#               64
#             ]
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": false
#           },
#           "synchronization": {
#             "enabled": false
#           }
#         }
#       },
#       "baseline": {
#         "model": {
#           "classifier": {
#             "type": "linear"
#           }
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": false
#           }
#         }
#       },
#       "high_performance": {
#         "model": {
#           "speaker_embedding": {
#             "dim": 512,
#             "hidden_dims": [
#               1024,
#               512,
#               256
#             ]
#           },
#           "classifier": {
#             "type": "cosine"
#           }
#         },
#         "training": {
#           "num_epochs": 200,
#           "batch_size": 64
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": true,
#             "warmup_epochs": 10
#           }
#         }
#       },
#       "robust": {
#         "model": {
#           "chaotic_embedding": {
#             "noise_level": 0.01
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": true,
#             "perturbation_scale": 0.15,
#             "warmup_epochs": 3
#           }
#         },
#         "audio": {
#           "augmentation": {
#             "enabled": true,
#             "noise_injection": 0.01
#           }
#         }
#       }
#     }
#   },
#   "num_speakers": 251,
#   "model_type": "full_chaotic",
#   "embedding_dim": 10,
#   "delay_method": "autocorr",
#   "mlsa_scales": 5,
#   "rqa_radius_ratio": 0.1,
#   "chaotic_system": "lorenz",
#   "evolution_time": 0.5,
#   "time_step": 0.01,
#   "coupling_strength": 1.0,
#   "noise_level": 0.001,
#   "pooling_type": "comprehensive",
#   "speaker_embedding_dim": 256,
#   "embedding_hidden_dims": [
#     512,
#     256,
#     128
#   ],
#   "classifier_type": "cosine",
#   "temperature": 30.0,
#   "margin": 0.35,
#   "batch_size": 32,
#   "num_epochs": 100,
#   "learning_rate": 0.0005,
#   "weight_decay": 0.0001,
#   "gradient_clipping": 1.0,
#   "optimizer": {
#     "type": "adamw",
#     "params": {
#       "betas": [
#         0.9,
#         0.999
#       ],
#       "eps": 1e-08,
#       "weight_decay": 0.0001
#     }
#   },
#   "scheduler": {
#     "type": "cosine",
#     "params": {
#       "T_max": 100,
#       "eta_min": 1e-06
#     }
#   },
#   "early_stopping": {
#     "patience": 30
#   },
#   "sample_rate": 16000,
#   "max_audio_length": 3.0,
#   "frame_length": 400,
#   "hop_length": 160,
#   "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#   "device": "auto",
#   "seed": 42,
#   "loss_config": {
#     "classification": {
#       "type": "cross_entropy",
#       "label_smoothing": 0.0
#     },
#     "stability": {
#       "enabled": true,
#       "weight": 0.1,
#       "target_lyapunov_range": [
#         0.1,
#         2.0
#       ],
#       "trajectory_bound": 50.0,
#       "collapse_threshold": 0.1,
#       "diversity_weight": 0.05
#     },
#     "synchronization": {
#       "enabled": false,
#       "sync_weight": 0.1,
#       "desync_weight": 0.1,
#       "margin": 1.0,
#       "sample_ratio": 1,
#       "distance_type": "euclidean"
#     },
#     "adversarial": {
#       "enabled": false,
#       "warmup_epochs": 5,
#       "perturbation_scale": 0.1,
#       "parameter_noise": true,
#       "trajectory_noise": true,
#       "weight": 0.3
#     }
#   },
#   "optional_modules": {
#     "bifurcation_control": {
#       "enabled": true,
#       "num_regimes": 4,
#       "hidden_dim": 32,
#       "control_strength": 0.5,
#       "learnable_boundaries": true
#     },
#     "differentiable_features": {
#       "enabled": true,
#       "lyapunov_dim": 8,
#       "rqa_dim": 6,
#       "additional_stats": true
#     }
#   },
#   "epochs": 100,
#   "optimize_parameters": true
# }
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - System info: {'platform': 'Linux-4.18.0-553.74.1.el8_10.x86_64-x86_64-with-glibc2.28', 'system': 'Linux', 'node': 'g1102.mahti.csc.fi', 'release': '4.18.0-553.74.1.el8_10.x86_64', 'version': '#1 SMP Sun Sep 7 09:23:35 EDT 2025', 'machine': 'x86_64', 'processor': 'x86_64', 'python_version': '3.12.10 (main, Jun  3 2025, 21:04:06) [GCC 8.5.0 20210514 (Red Hat 8.5.0-26)]', 'python_executable': '/usr/bin/python', 'cpu_count': 256, 'total_memory': 540285169664, 'available_memory': 515455078400, 'gpu_info': {'cuda_available': True, 'cuda_version': '12.6', 'gpu_count': 1, 'gpu_names': ['NVIDIA A100-SXM4-40GB MIG 1g.5gb']}, 'package_versions': {'numpy': '1.26.4', 'scipy': '1.13.1', 'scikit-learn': 'not installed', 'librosa': '0.11.0', 'soundfile': '0.13.1', 'torch': '2.7.1+cu126', 'tensorflow': 'not installed', 'matplotlib': '3.10.3', 'pandas': '2.3.0'}, 'git_info': {'commit_hash': '799b8c2069de765fb1cb2a2a54a61d3883986433', 'branch': 'origin', 'is_dirty': True}}
# INFO:chaotic_trainer:System info: {'platform': 'Linux-4.18.0-553.74.1.el8_10.x86_64-x86_64-with-glibc2.28', 'system': 'Linux', 'node': 'g1102.mahti.csc.fi', 'release': '4.18.0-553.74.1.el8_10.x86_64', 'version': '#1 SMP Sun Sep 7 09:23:35 EDT 2025', 'machine': 'x86_64', 'processor': 'x86_64', 'python_version': '3.12.10 (main, Jun  3 2025, 21:04:06) [GCC 8.5.0 20210514 (Red Hat 8.5.0-26)]', 'python_executable': '/usr/bin/python', 'cpu_count': 256, 'total_memory': 540285169664, 'available_memory': 515455078400, 'gpu_info': {'cuda_available': True, 'cuda_version': '12.6', 'gpu_count': 1, 'gpu_names': ['NVIDIA A100-SXM4-40GB MIG 1g.5gb']}, 'package_versions': {'numpy': '1.26.4', 'scipy': '1.13.1', 'scikit-learn': 'not installed', 'librosa': '0.11.0', 'soundfile': '0.13.1', 'torch': '2.7.1+cu126', 'tensorflow': 'not installed', 'matplotlib': '3.10.3', 'pandas': '2.3.0'}, 'git_info': {'commit_hash': '799b8c2069de765fb1cb2a2a54a61d3883986433', 'branch': 'origin', 'is_dirty': True}}
# Starting chaotic neural network training...
# Systems: ['lorenz']
# Model types: ['full_chaotic']
# Runs per configuration: 1
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - Training 1 systems × 1 types × 1 runs...
# INFO:chaotic_trainer:Training 1 systems × 1 types × 1 runs...
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - Systems: ['lorenz']
# INFO:chaotic_trainer:Systems: ['lorenz']
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - Model types: ['full_chaotic']
# INFO:chaotic_trainer:Model types: ['full_chaotic']
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO -
# ============================================================
# INFO:chaotic_trainer:
# ============================================================
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - TRAINING: LORENZ + FULL_CHAOTIC
# INFO:chaotic_trainer:TRAINING: LORENZ + FULL_CHAOTIC
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - Training chaotic_lorenz_full_chaotic_run_0...
# INFO:chaotic_trainer:Training chaotic_lorenz_full_chaotic_run_0...
# 2026-02-23 09:26:25,711 - chaotic_trainer - INFO - Optimizing parameters for lorenz system...
# INFO:chaotic_trainer:Optimizing parameters for lorenz system...
# CheckpointManager initialized for experiment: exp_20260223_092625
# Checkpoint directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Environment information collected
# [2026-02-23 09:26:25] [INFO] Configuring deterministic operations
# [2026-02-23 09:26:25] [INFO] PyTorch deterministic operations configured
# [2026-02-23 09:26:25] [INFO] Starting reproducibility verification
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Operation 1 is reproducible
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Operation 2 is reproducible
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Operation 3 is reproducible
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Operation 4 is reproducible
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Setting global random seed to: 42
# [2026-02-23 09:26:25] [INFO] Python random seed set
# [2026-02-23 09:26:25] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:26:25] [INFO] NumPy random seed set
# [2026-02-23 09:26:25] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:26:25] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:26:25] [INFO] PyTorch seeds set
# [2026-02-23 09:26:25] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:26:25] [INFO] Operation 5 is reproducible
# [2026-02-23 09:26:25] [SUCCESS] All operations are reproducible
#
# ============================================================
# REPRODUCIBILITY SUMMARY
# ============================================================
# Seed: 42
# Strict Mode: True
# Environment Hash: c120ac5d69eafb43
# Python Version: 3.12.10
#
# Available Libraries:
#   numpy: 1.26.4
#   torch: 2.7.1+cu126
#   cuda_version: 12.6
#   cudnn_version: 91002
#   librosa: 0.11.0
#   soundfile: 0.13.1
#
# Environment Variables:
#   PYTHONHASHSEED: 42
#   CUDA_VISIBLE_DEVICES: MIG-24ae1daa-9c0a-5c0f-bbc1-bacbeac9256d
#   OMP_NUM_THREADS: 1
#   MKL_NUM_THREADS: 1
# ============================================================
# 2026-02-23 09:26:25,784 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Initialized experiment: chaotic_lorenz_full_chaotic_run_0
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Initialized experiment: chaotic_lorenz_full_chaotic_run_0
# 2026-02-23 09:26:25,799 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Device: cuda
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Device: cuda
# 2026-02-23 09:26:25,799 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0
# 2026-02-23 09:26:25,799 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Initialized chaotic network experiment with lorenz system
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Initialized chaotic network experiment with lorenz system
# 2026-02-23 09:26:25,799 - chaotic_trainer - INFO - Setting up chaotic_lorenz_full_chaotic_run_0...
# INFO:chaotic_trainer:Setting up chaotic_lorenz_full_chaotic_run_0...
# 2026-02-23 09:26:25,800 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Setting up experiment components...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Setting up experiment components...
# 2026-02-23 09:26:25,800 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating dataloaders...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating dataloaders...
# ====================
# Trying to load dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# ====================
# Loading LibriSpeech dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Dataset validation: 0 speakers, 0 files
# Loading subsets: ['7976', '1988', '8297', '5895', '3000', '5694', '1462', '1272', '777', '84', '6295', '3536', '2803', '3576', '8842', '7850', '2035', '2412', '3752', '251', '174', '5338', '6241', '2428', '6319', '1993']
# Created label mapping for 26 speakers: labels in [0, 25]
# Dataset loaded: 679 samples from 26 speakers
# Split dataset with train: 472 sample, 26 speakers
# Split dataset with val: 89 sample, 26 speakers
# Split dataset with test: 118 sample, 26 speakers
# 2026-02-23 09:26:44,754 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Detected 26 speakers in dataset
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Detected 26 speakers in dataset
# 2026-02-23 09:26:44,754 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Dataloaders created:
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Dataloaders created:
# 2026-02-23 09:26:44,754 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Train: 14 batches
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Train: 14 batches
# 2026-02-23 09:26:44,754 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Val: 3 batches
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Val: 3 batches
# 2026-02-23 09:26:44,754 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Test: 4 batches
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Test: 4 batches
# 2026-02-23 09:26:44,754 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating model...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating model...
# 2026-02-23 09:26:44,754 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Using actual num_speakers from dataset: 26
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Using actual num_speakers from dataset: 26
# [CONFIG DEBUG] Phase space: dim=10, delay_method=autocorr, dimension_method=false_neighbors
# Chaotic feature dimensions: MLSA=105, RQA=125, Total=230
# [NETWORK DEBUG] ChaoticEmbedding created with:
#   use_bifurcation_control=True
#   bifurcation_net exists: False
# [INIT] Registered diff_feat_projection: 270 -> 230
# [GRADIENT FIX] Differentiable chaos features enabled: output_dim=270
# [GRADIENT FIX] Added differentiable raw audio path
#
# ============================================================
# ENHANCED CHAOTIC NETWORK INITIALIZED
# ============================================================
# Total parameters: 592,487
# Parameters per speaker: 22788
# Speaker embedding dim: 256
# Hidden dims: [512, 256, 128]
# ============================================================
#
# 2026-02-23 09:27:50,905 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Total parameters: 592,487
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Total parameters: 592,487
# 2026-02-23 09:27:50,905 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Trainable parameters: 592,487
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Trainable parameters: 592,487
# 2026-02-23 09:27:50,905 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating optimizer...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating optimizer...
# 2026-02-23 09:27:53,374 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Optimizer: AdamW
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Optimizer: AdamW
# 2026-02-23 09:27:53,374 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating scheduler...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating scheduler...
# 2026-02-23 09:27:53,374 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Scheduler: CosineAnnealingLR
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Scheduler: CosineAnnealingLR
# 2026-02-23 09:27:53,374 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating criterion...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating criterion...
# 2026-02-23 09:27:53,374 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Criterion: CrossEntropyLoss
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Criterion: CrossEntropyLoss
# 2026-02-23 09:27:53,444 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Configuration saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/config.json
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Configuration saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/config.json
# 2026-02-23 09:27:53,444 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Experiment setup completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Experiment setup completed
# 2026-02-23 09:27:53,445 - chaotic_trainer - INFO - 🚀 No checkpoint specified, starting from scratch
# INFO:chaotic_trainer:🚀 No checkpoint specified, starting from scratch
# 2026-02-23 09:27:53,445 - chaotic_trainer - INFO - Model parameters: 592,487 (trainable: 592,487)
# INFO:chaotic_trainer:Model parameters: 592,487 (trainable: 592,487)
# 2026-02-23 09:27:53,445 - chaotic_trainer - INFO - Training with chaotic dynamics monitoring...
# INFO:chaotic_trainer:Training with chaotic dynamics monitoring...
# 2026-02-23 09:27:53,445 - chaotic_trainer - INFO - Starting training from epoch 0 for 100 more epochs...
# INFO:chaotic_trainer:Starting training from epoch 0 for 100 more epochs...
# 2026-02-23 09:27:53,445 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Starting training for 100 epochs
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Starting training for 100 epochs
# 2026-02-23 09:27:54,403 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -
# ================================================================================
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:
# ================================================================================
# 2026-02-23 09:27:54,403 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - COMPREHENSIVE DEBUG - FIRST BATCH
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:COMPREHENSIVE DEBUG - FIRST BATCH
# 2026-02-23 09:27:54,403 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - ================================================================================
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:================================================================================
# 2026-02-23 09:27:54,403 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Batch Info:
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Batch Info:
# 2026-02-23 09:27:54,403 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Audio shape: torch.Size([32, 48000])
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Audio shape: torch.Size([32, 48000])
# 2026-02-23 09:27:54,403 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Targets shape: torch.Size([32])
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Targets shape: torch.Size([32])
# 2026-02-23 09:27:54,409 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Targets (first 8): tensor([22, 21,  7,  1,  9, 16, 25, 12], device='cuda:0')
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Targets (first 8): tensor([22, 21,  7,  1,  9, 16, 25, 12], device='cuda:0')
# 2026-02-23 09:27:57,874 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - ================================================================================
#
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:================================================================================
#
# 2026-02-23 09:27:58,042 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - [STABILITY] Initialized LyapunovStabilityLoss
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] Initialized LyapunovStabilityLoss
# 2026-02-23 09:27:58,077 - experiment_chaotic_lorenz_full_chaotic_run_0 - DEBUG - [STABILITY] lyap=0.102, max_norm=70.8, min_std=13.908
# DEBUG:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] lyap=0.102, max_norm=70.8, min_std=13.908
# 2026-02-23 09:27:59,384 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 0: [0/472 (0.0%)]	Loss: 6.706853
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 0: [0/472 (0.0%)]	Loss: 6.706853
# 2026-02-23 09:28:05,663 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 0: Train Loss: 6.1947, Train Acc: 0.0402, Val Loss: 4.0200, Val Acc: 0.0449
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 0: Train Loss: 6.1947, Train Acc: 0.0402, Val Loss: 4.0200, Val Acc: 0.0449
# ...
# DEBUG:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] lyap=0.080, max_norm=46.6, min_std=7.894
# 2026-02-23 09:36:38,965 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 85: Train Loss: 0.1760, Train Acc: 0.9554, Val Loss: 0.1137, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 85: Train Loss: 0.1760, Train Acc: 0.9554, Val Loss: 0.1137, Val Acc: 0.9663
# 2026-02-23 09:36:39,503 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 86: [0/472 (0.0%)]	Loss: 0.200560
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 86: [0/472 (0.0%)]	Loss: 0.200560
# 2026-02-23 09:36:45,045 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 86: Train Loss: 0.2061, Train Acc: 0.9375, Val Loss: 0.1142, Val Acc: 0.9551
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 86: Train Loss: 0.2061, Train Acc: 0.9375, Val Loss: 0.1142, Val Acc: 0.9551
# 2026-02-23 09:36:45,593 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 87: [0/472 (0.0%)]	Loss: 0.196230
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 87: [0/472 (0.0%)]	Loss: 0.196230
# 2026-02-23 09:36:51,140 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 87: Train Loss: 0.2052, Train Acc: 0.9554, Val Loss: 0.1343, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 87: Train Loss: 0.2052, Train Acc: 0.9554, Val Loss: 0.1343, Val Acc: 0.9663
# 2026-02-23 09:36:51,673 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 88: [0/472 (0.0%)]	Loss: 0.109795
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 88: [0/472 (0.0%)]	Loss: 0.109795
# 2026-02-23 09:36:57,255 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 88: Train Loss: 0.1373, Train Acc: 0.9643, Val Loss: 0.1180, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 88: Train Loss: 0.1373, Train Acc: 0.9643, Val Loss: 0.1180, Val Acc: 0.9663
# 2026-02-23 09:36:57,800 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 89: [0/472 (0.0%)]	Loss: 0.242580
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 89: [0/472 (0.0%)]	Loss: 0.242580
# 2026-02-23 09:37:03,389 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 89: Train Loss: 0.1788, Train Acc: 0.9442, Val Loss: 0.1138, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 89: Train Loss: 0.1788, Train Acc: 0.9442, Val Loss: 0.1138, Val Acc: 0.9775
# Removed old checkpoint: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/latest.pt
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/checkpoint_epoch_0089.pt
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/best_model.pt
# 2026-02-23 09:37:03,465 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Saved new best model at epoch 89
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Saved new best model at epoch 89
# Removed old checkpoint: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/latest.pt
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/latest.pt
# 2026-02-23 09:37:04,036 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 90: [0/472 (0.0%)]	Loss: 0.102662
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 90: [0/472 (0.0%)]	Loss: 0.102662
# 2026-02-23 09:37:09,555 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 90: Train Loss: 0.1718, Train Acc: 0.9464, Val Loss: 0.1063, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 90: Train Loss: 0.1718, Train Acc: 0.9464, Val Loss: 0.1063, Val Acc: 0.9775
# Removed old checkpoint: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/checkpoint_epoch_0080.pt
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/checkpoint_epoch_0090.pt
# Removed old checkpoint: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/latest.pt
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_092625/latest.pt
# 2026-02-23 09:37:10,174 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 91: [0/472 (0.0%)]	Loss: 0.127691
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 91: [0/472 (0.0%)]	Loss: 0.127691
# 2026-02-23 09:37:15,744 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 91: Train Loss: 0.1458, Train Acc: 0.9688, Val Loss: 0.1061, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 91: Train Loss: 0.1458, Train Acc: 0.9688, Val Loss: 0.1061, Val Acc: 0.9775
# 2026-02-23 09:37:16,273 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 92: [0/472 (0.0%)]	Loss: 0.106862
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 92: [0/472 (0.0%)]	Loss: 0.106862
# 2026-02-23 09:37:19,878 - experiment_chaotic_lorenz_full_chaotic_run_0 - DEBUG - [STABILITY] lyap=0.081, max_norm=46.6, min_std=7.945
# DEBUG:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] lyap=0.081, max_norm=46.6, min_std=7.945
# 2026-02-23 09:37:21,768 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 92: Train Loss: 0.1248, Train Acc: 0.9710, Val Loss: 0.1027, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 92: Train Loss: 0.1248, Train Acc: 0.9710, Val Loss: 0.1027, Val Acc: 0.9775
# 2026-02-23 09:37:22,305 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 93: [0/472 (0.0%)]	Loss: 0.163653
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 93: [0/472 (0.0%)]	Loss: 0.163653
# 2026-02-23 09:37:27,820 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 93: Train Loss: 0.1142, Train Acc: 0.9710, Val Loss: 0.1065, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 93: Train Loss: 0.1142, Train Acc: 0.9710, Val Loss: 0.1065, Val Acc: 0.9663
# 2026-02-23 09:37:28,348 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 94: [0/472 (0.0%)]	Loss: 0.124084
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 94: [0/472 (0.0%)]	Loss: 0.124084
# 2026-02-23 09:37:33,877 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 94: Train Loss: 0.1766, Train Acc: 0.9509, Val Loss: 0.1027, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 94: Train Loss: 0.1766, Train Acc: 0.9509, Val Loss: 0.1027, Val Acc: 0.9663
# 2026-02-23 09:37:34,418 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 95: [0/472 (0.0%)]	Loss: 0.319619
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 95: [0/472 (0.0%)]	Loss: 0.319619
# 2026-02-23 09:37:39,952 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 95: Train Loss: 0.1821, Train Acc: 0.9487, Val Loss: 0.1185, Val Acc: 0.9438
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 95: Train Loss: 0.1821, Train Acc: 0.9487, Val Loss: 0.1185, Val Acc: 0.9438
# 2026-02-23 09:37:40,477 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 96: [0/472 (0.0%)]	Loss: 0.189965
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 96: [0/472 (0.0%)]	Loss: 0.189965
# 2026-02-23 09:37:45,961 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 96: Train Loss: 0.1688, Train Acc: 0.9576, Val Loss: 0.1128, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 96: Train Loss: 0.1688, Train Acc: 0.9576, Val Loss: 0.1128, Val Acc: 0.9775
# 2026-02-23 09:37:46,496 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 97: [0/472 (0.0%)]	Loss: 0.116298
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 97: [0/472 (0.0%)]	Loss: 0.116298
# 2026-02-23 09:37:52,021 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 97: Train Loss: 0.2054, Train Acc: 0.9464, Val Loss: 0.0987, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 97: Train Loss: 0.2054, Train Acc: 0.9464, Val Loss: 0.0987, Val Acc: 0.9775
# 2026-02-23 09:37:52,559 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 98: [0/472 (0.0%)]	Loss: 0.212623
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 98: [0/472 (0.0%)]	Loss: 0.212623
# 2026-02-23 09:37:58,106 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 98: Train Loss: 0.1896, Train Acc: 0.9487, Val Loss: 0.1025, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 98: Train Loss: 0.1896, Train Acc: 0.9487, Val Loss: 0.1025, Val Acc: 0.9663
# 2026-02-23 09:37:58,649 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 99: [0/472 (0.0%)]	Loss: 0.258265
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 99: [0/472 (0.0%)]	Loss: 0.258265
# 2026-02-23 09:38:04,194 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 99: Train Loss: 0.2295, Train Acc: 0.9107, Val Loss: 0.1148, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 99: Train Loss: 0.2295, Train Acc: 0.9107, Val Loss: 0.1148, Val Acc: 0.9663
# 2026-02-23 09:38:04,200 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Running final test evaluation...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Running final test evaluation...
# 2026-02-23 09:38:06,402 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Test Results:
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Test Results:
# 2026-02-23 09:38:06,402 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   loss: 0.1561
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  loss: 0.1561
# 2026-02-23 09:38:06,402 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   accuracy: 0.9492
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  accuracy: 0.9492
# 2026-02-23 09:38:06,402 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   avg_confidence: 0.9935
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  avg_confidence: 0.9935
# 2026-02-23 09:38:06,402 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   embedding_diversity: 0.1096
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  embedding_diversity: 0.1096
# 2026-02-23 09:38:06,402 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   embedding_norm_mean: 1.0000
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  embedding_norm_mean: 1.0000
# 2026-02-23 09:38:06,403 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   embedding_norm_std: 0.0000
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  embedding_norm_std: 0.0000
# 2026-02-23 09:38:06,404 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Training completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Training completed
# 2026-02-23 09:38:06,404 - chaotic_trainer - INFO - Evaluating chaotic_lorenz_full_chaotic_run_0...
# INFO:chaotic_trainer:Evaluating chaotic_lorenz_full_chaotic_run_0...
# 2026-02-23 09:38:07,176 - chaotic_trainer - INFO - Running chaotic analysis...
# INFO:chaotic_trainer:Running chaotic analysis...
# 2026-02-23 09:38:07,176 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Running comprehensive chaotic network analysis...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Running comprehensive chaotic network analysis...
# 2026-02-23 09:38:07,177 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Analyzing chaotic features and dynamics...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Analyzing chaotic features and dynamics...
# 2026-02-23 09:38:08,183 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Chaotic analysis completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Chaotic analysis completed
# 2026-02-23 09:38:08,185 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating chaotic dynamics visualizations...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating chaotic dynamics visualizations...
# 2026-02-23 09:38:10,646 - experiment_chaotic_lorenz_full_chaotic_run_0 - WARNING - Embedding plotting failed: boolean index did not match indexed array along dimension 0; dimension is 8 but corresponding boolean dimension is 32
# WARNING:experiment_chaotic_lorenz_full_chaotic_run_0:Embedding plotting failed: boolean index did not match indexed array along dimension 0; dimension is 8 but corresponding boolean dimension is 32
# 2026-02-23 09:38:10,652 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Chaotic network analysis completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Chaotic network analysis completed
# 2026-02-23 09:38:10,652 - chaotic_trainer - INFO - Completed chaotic_lorenz_full_chaotic_run_0: Accuracy: 0.9492, Loss: 0.1561, Time: 700.6s
# INFO:chaotic_trainer:Completed chaotic_lorenz_full_chaotic_run_0: Accuracy: 0.9492, Loss: 0.1561, Time: 700.6s
# 2026-02-23 09:38:10,661 - chaotic_trainer - INFO - Progress: 1/1 (100.0%)
# INFO:chaotic_trainer:Progress: 1/1 (100.0%)
# 2026-02-23 09:38:10,661 - chaotic_trainer - INFO - lorenz + full_chaotic Summary: 0.9492 ± 0.0000
# INFO:chaotic_trainer:lorenz + full_chaotic Summary: 0.9492 ± 0.0000
# 2026-02-23 09:38:10,662 - chaotic_trainer - INFO - Analyzing chaotic training results...
# INFO:chaotic_trainer:Analyzing chaotic training results...
# 2026-02-23 09:38:10,663 - chaotic_trainer - INFO - Generating comprehensive chaotic training report...
# INFO:chaotic_trainer:Generating comprehensive chaotic training report...
# 2026-02-23 09:38:12,529 - chaotic_trainer - INFO - Visualizations saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/visualizations
# INFO:chaotic_trainer:Visualizations saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/visualizations
# 2026-02-23 09:38:12,529 - chaotic_trainer - INFO - Reports generated:
# INFO:chaotic_trainer:Reports generated:
# 2026-02-23 09:38:12,529 - chaotic_trainer - INFO -   Text report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/chaotic_training_report.txt
# INFO:chaotic_trainer:  Text report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/chaotic_training_report.txt
# 2026-02-23 09:38:12,529 - chaotic_trainer - INFO -   JSON report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/chaotic_training_results.json
# INFO:chaotic_trainer:  JSON report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On/chaotic_training_results.json
#
# ============================================================
# CHAOTIC TRAINING COMPLETED
# ============================================================
# Best configuration: lorenz + full_chaotic
# Best accuracy: 0.9492
#
# Systems performance:
#   lorenz: 0.9492 ± 0.0000
# Results saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/On
# 2026-02-23 09:38:12,530 - chaotic_trainer - INFO - Chaotic training completed.
# INFO:chaotic_trainer:Chaotic training completed.
# 2026-02-23 09:38:12,530 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================

# %% [markdown]
# ### 对比实验：bifurcation_control = "false"

# %%
# !python /scratch/project_2003370/yueyao/Model/scripts/train_chaotic.py \
    --system lorenz \
    --epochs 100 \
    --batch_size 32 \
    --output_dir  /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off \
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --config /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/chaotic_config_off.yaml
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#   ✓ Dataset loader imported successfully
# ✓ Data package initialized (circular import free)
# All required modules imported successfully!
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Environment information collected
# [2026-02-23 09:38:18] [INFO] Configuring deterministic operations
# [2026-02-23 09:38:18] [INFO] PyTorch deterministic operations configured
# [2026-02-23 09:38:18] [INFO] Starting reproducibility verification
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 1 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 2 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 3 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 4 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 5 is reproducible
# [2026-02-23 09:38:18] [SUCCESS] All operations are reproducible
#
# ============================================================
# REPRODUCIBILITY SUMMARY
# ============================================================
# Seed: 42
# Strict Mode: True
# Environment Hash: 86a51d5a9ce6aabb
# Python Version: 3.12.10
#
# Available Libraries:
#   numpy: 1.26.4
#   torch: 2.7.1+cu126
#   cuda_version: 12.6
#   cudnn_version: 91002
#   librosa: 0.11.0
#   soundfile: 0.13.1
#
# Environment Variables:
#   PYTHONHASHSEED: 42
#   CUDA_VISIBLE_DEVICES: MIG-24ae1daa-9c0a-5c0f-bbc1-bacbeac9256d
#   OMP_NUM_THREADS: not_set
#   MKL_NUM_THREADS: not_set
# ============================================================
# 2026-02-23 09:38:18,705 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================
# 2026-02-23 09:38:18,713 - chaotic_trainer - INFO - CHAOTIC NEURAL NETWORKS TRAINING
# INFO:chaotic_trainer:CHAOTIC NEURAL NETWORKS TRAINING
# 2026-02-23 09:38:18,713 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================
# 2026-02-23 09:38:18,713 - chaotic_trainer - INFO - Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off
# INFO:chaotic_trainer:Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off
# 2026-02-23 09:38:18,713 - chaotic_trainer - INFO - Configuration: {
#   "_nested": {
#     "experiment": {
#       "name": "bifurcation_off",
#       "author": "C-HiLAP Project"
#     },
#     "data": {
#       "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#       "train_split": 0.7,
#       "val_split": 0.15,
#       "test_split": 0.15,
#       "num_workers": 4,
#       "pin_memory": true,
#       "prefetch_factor": 2,
#       "cache_features": false,
#       "cache_dir": "./cache"
#     },
#     "audio": {
#       "sample_rate": 16000,
#       "max_audio_length": 3.0,
#       "min_audio_length": 0.5,
#       "frame_length": 400,
#       "hop_length": 160,
#       "normalize": true,
#       "remove_silence": false,
#       "augmentation": {
#         "enabled": false,
#         "noise_injection": 0.005,
#         "time_stretch_range": [
#           0.9,
#           1.1
#         ],
#         "pitch_shift_range": [
#           -2,
#           2
#         ]
#       }
#     },
#     "model": {
#       "type": "full_chaotic",
#       "num_speakers": 251,
#       "phase_space": {
#         "embedding_dim": 10,
#         "delay_method": "autocorr",
#         "dimension_method": "false_neighbors",
#         "fixed_delay": 10
#       },
#       "chaotic_features": {
#         "mlsa": {
#           "scales": 5,
#           "max_lyapunov_steps": 1000
#         },
#         "rqa": {
#           "radius_ratio": 0.1,
#           "min_line_length": 2
#         }
#       },
#       "chaotic_embedding": {
#         "system_type": "lorenz",
#         "evolution_time": 0.5,
#         "time_step": 0.01,
#         "coupling_strength": 1.0,
#         "noise_level": 0.001,
#         "lorenz": {
#           "sigma": 10.0,
#           "rho": 28.0,
#           "beta": 2.6667
#         },
#         "rossler": {
#           "a": 0.2,
#           "b": 0.2,
#           "c": 5.7
#         }
#       },
#       "attractor_pooling": {
#         "type": "comprehensive",
#         "correlation_dimension": {
#           "num_radii": 50
#         }
#       },
#       "speaker_embedding": {
#         "dim": 256,
#         "hidden_dims": [
#           512,
#           256,
#           128
#         ],
#         "dropout_rate": 0.3,
#         "use_batch_norm": true
#       },
#       "classifier": {
#         "type": "cosine",
#         "temperature": 30.0,
#         "margin": 0.35,
#         "plda": {
#           "latent_dim": 128,
#           "use_length_norm": true
#         }
#       }
#     },
#     "optional_modules": {
#       "bifurcation_control": {
#         "enabled": false
#       },
#       "differentiable_features": {
#         "enabled": true,
#         "lyapunov_dim": 8,
#         "rqa_dim": 6,
#         "additional_stats": true
#       }
#     },
#     "loss": {
#       "classification": {
#         "type": "cross_entropy",
#         "label_smoothing": 0.0
#       },
#       "stability": {
#         "enabled": true,
#         "weight": 0.1,
#         "target_lyapunov_range": [
#           0.1,
#           2.0
#         ],
#         "trajectory_bound": 50.0,
#         "collapse_threshold": 0.1,
#         "diversity_weight": 0.05
#       },
#       "synchronization": {
#         "enabled": false,
#         "sync_weight": 0.1,
#         "desync_weight": 0.1,
#         "margin": 1.0,
#         "sample_ratio": 0.3,
#         "distance_type": "euclidean"
#       },
#       "adversarial": {
#         "enabled": true,
#         "warmup_epochs": 5,
#         "perturbation_scale": 0.1,
#         "parameter_noise": true,
#         "trajectory_noise": true,
#         "weight": 0.3
#       }
#     },
#     "training": {
#       "batch_size": 32,
#       "num_epochs": 100,
#       "gradient_clipping": 1.0,
#       "gradient_accumulation_steps": 1,
#       "mixed_precision": false,
#       "optimizer": {
#         "type": "adamw",
#         "learning_rate": 0.0005,
#         "weight_decay": 0.0001,
#         "betas": [
#           0.9,
#           0.999
#         ],
#         "eps": 1e-08,
#         "momentum": 0.9,
#         "nesterov": true
#       },
#       "scheduler": {
#         "type": "cosine",
#         "T_max": 100,
#         "eta_min": 1e-06,
#         "step_size": 30,
#         "gamma": 0.1,
#         "patience": 10,
#         "factor": 0.5,
#         "min_lr": 1e-07,
#         "warmup_epochs": 5,
#         "warmup_start_lr": 1e-06
#       },
#       "early_stopping": {
#         "enabled": true,
#         "patience": 30,
#         "min_delta": 0.001,
#         "monitor": "val_accuracy",
#         "mode": "max"
#       },
#       "checkpoint": {
#         "save_best_only": true,
#         "save_frequency": 10,
#         "max_to_keep": 3
#       }
#     },
#     "evaluation": {
#       "metrics": [
#         "accuracy",
#         "top5_accuracy",
#         "eer",
#         "dcf"
#       ],
#       "eval_frequency": 1,
#       "visualization": {
#         "enabled": true,
#         "plot_confusion_matrix": true,
#         "plot_embeddings": true,
#         "plot_attractors": true
#       }
#     },
#     "logging": {
#       "level": "INFO",
#       "tensorboard": {
#         "enabled": true,
#         "log_dir": "./runs"
#       },
#       "wandb": {
#         "enabled": false,
#         "project": "chaotic-speaker-recognition",
#         "entity": null
#       },
#       "log_frequency": 50
#     },
#     "output": {
#       "base_dir": "./experiments/outputs",
#       "save_predictions": true,
#       "save_embeddings": true,
#       "save_analysis": true
#     },
#     "hardware": {
#       "device": "auto",
#       "seed": 42,
#       "deterministic": false,
#       "benchmark": true
#     },
#     "presets": {
#       "fast_debug": {
#         "training": {
#           "batch_size": 8,
#           "num_epochs": 5
#         },
#         "model": {
#           "speaker_embedding": {
#             "hidden_dims": [
#               128,
#               64
#             ]
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": false
#           },
#           "synchronization": {
#             "enabled": false
#           }
#         }
#       },
#       "baseline": {
#         "model": {
#           "classifier": {
#             "type": "linear"
#           }
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": false
#           }
#         }
#       },
#       "high_performance": {
#         "model": {
#           "speaker_embedding": {
#             "dim": 512,
#             "hidden_dims": [
#               1024,
#               512,
#               256
#             ]
#           },
#           "classifier": {
#             "type": "cosine"
#           }
#         },
#         "training": {
#           "num_epochs": 200,
#           "batch_size": 64
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": true,
#             "warmup_epochs": 10
#           }
#         }
#       },
#       "robust": {
#         "model": {
#           "chaotic_embedding": {
#             "noise_level": 0.01
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": true,
#             "perturbation_scale": 0.15,
#             "warmup_epochs": 3
#           }
#         },
#         "audio": {
#           "augmentation": {
#             "enabled": true,
#             "noise_injection": 0.01
#           }
#         }
#       }
#     }
#   },
#   "num_speakers": 251,
#   "model_type": "full_chaotic",
#   "embedding_dim": 10,
#   "delay_method": "autocorr",
#   "mlsa_scales": 5,
#   "rqa_radius_ratio": 0.1,
#   "chaotic_system": "lorenz",
#   "evolution_time": 0.5,
#   "time_step": 0.01,
#   "coupling_strength": 1.0,
#   "noise_level": 0.001,
#   "pooling_type": "comprehensive",
#   "speaker_embedding_dim": 256,
#   "embedding_hidden_dims": [
#     512,
#     256,
#     128
#   ],
#   "classifier_type": "cosine",
#   "temperature": 30.0,
#   "margin": 0.35,
#   "batch_size": 32,
#   "num_epochs": 100,
#   "learning_rate": 0.0005,
#   "weight_decay": 0.0001,
#   "gradient_clipping": 1.0,
#   "optimizer": {
#     "type": "adamw",
#     "params": {
#       "betas": [
#         0.9,
#         0.999
#       ],
#       "eps": 1e-08,
#       "weight_decay": 0.0001
#     }
#   },
#   "scheduler": {
#     "type": "cosine",
#     "params": {
#       "T_max": 100,
#       "eta_min": 1e-06
#     }
#   },
#   "early_stopping": {
#     "patience": 30
#   },
#   "sample_rate": 16000,
#   "max_audio_length": 3.0,
#   "frame_length": 400,
#   "hop_length": 160,
#   "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#   "device": "auto",
#   "seed": 42,
#   "loss_config": {
#     "classification": {
#       "type": "cross_entropy",
#       "label_smoothing": 0.0
#     },
#     "stability": {
#       "enabled": true,
#       "weight": 0.1,
#       "target_lyapunov_range": [
#         0.1,
#         2.0
#       ],
#       "trajectory_bound": 50.0,
#       "collapse_threshold": 0.1,
#       "diversity_weight": 0.05
#     },
#     "synchronization": {
#       "enabled": false,
#       "sync_weight": 0.1,
#       "desync_weight": 0.1,
#       "margin": 1.0,
#       "sample_ratio": 0.3,
#       "distance_type": "euclidean"
#     },
#     "adversarial": {
#       "enabled": true,
#       "warmup_epochs": 5,
#       "perturbation_scale": 0.1,
#       "parameter_noise": true,
#       "trajectory_noise": true,
#       "weight": 0.3
#     }
#   },
#   "optional_modules": {
#     "bifurcation_control": {
#       "enabled": false
#     },
#     "differentiable_features": {
#       "enabled": true,
#       "lyapunov_dim": 8,
#       "rqa_dim": 6,
#       "additional_stats": true
#     }
#   },
#   "epochs": 100,
#   "optimize_parameters": true
# }
# INFO:chaotic_trainer:Configuration: {
#   "_nested": {
#     "experiment": {
#       "name": "bifurcation_off",
#       "author": "C-HiLAP Project"
#     },
#     "data": {
#       "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#       "train_split": 0.7,
#       "val_split": 0.15,
#       "test_split": 0.15,
#       "num_workers": 4,
#       "pin_memory": true,
#       "prefetch_factor": 2,
#       "cache_features": false,
#       "cache_dir": "./cache"
#     },
#     "audio": {
#       "sample_rate": 16000,
#       "max_audio_length": 3.0,
#       "min_audio_length": 0.5,
#       "frame_length": 400,
#       "hop_length": 160,
#       "normalize": true,
#       "remove_silence": false,
#       "augmentation": {
#         "enabled": false,
#         "noise_injection": 0.005,
#         "time_stretch_range": [
#           0.9,
#           1.1
#         ],
#         "pitch_shift_range": [
#           -2,
#           2
#         ]
#       }
#     },
#     "model": {
#       "type": "full_chaotic",
#       "num_speakers": 251,
#       "phase_space": {
#         "embedding_dim": 10,
#         "delay_method": "autocorr",
#         "dimension_method": "false_neighbors",
#         "fixed_delay": 10
#       },
#       "chaotic_features": {
#         "mlsa": {
#           "scales": 5,
#           "max_lyapunov_steps": 1000
#         },
#         "rqa": {
#           "radius_ratio": 0.1,
#           "min_line_length": 2
#         }
#       },
#       "chaotic_embedding": {
#         "system_type": "lorenz",
#         "evolution_time": 0.5,
#         "time_step": 0.01,
#         "coupling_strength": 1.0,
#         "noise_level": 0.001,
#         "lorenz": {
#           "sigma": 10.0,
#           "rho": 28.0,
#           "beta": 2.6667
#         },
#         "rossler": {
#           "a": 0.2,
#           "b": 0.2,
#           "c": 5.7
#         }
#       },
#       "attractor_pooling": {
#         "type": "comprehensive",
#         "correlation_dimension": {
#           "num_radii": 50
#         }
#       },
#       "speaker_embedding": {
#         "dim": 256,
#         "hidden_dims": [
#           512,
#           256,
#           128
#         ],
#         "dropout_rate": 0.3,
#         "use_batch_norm": true
#       },
#       "classifier": {
#         "type": "cosine",
#         "temperature": 30.0,
#         "margin": 0.35,
#         "plda": {
#           "latent_dim": 128,
#           "use_length_norm": true
#         }
#       }
#     },
#     "optional_modules": {
#       "bifurcation_control": {
#         "enabled": false
#       },
#       "differentiable_features": {
#         "enabled": true,
#         "lyapunov_dim": 8,
#         "rqa_dim": 6,
#         "additional_stats": true
#       }
#     },
#     "loss": {
#       "classification": {
#         "type": "cross_entropy",
#         "label_smoothing": 0.0
#       },
#       "stability": {
#         "enabled": true,
#         "weight": 0.1,
#         "target_lyapunov_range": [
#           0.1,
#           2.0
#         ],
#         "trajectory_bound": 50.0,
#         "collapse_threshold": 0.1,
#         "diversity_weight": 0.05
#       },
#       "synchronization": {
#         "enabled": false,
#         "sync_weight": 0.1,
#         "desync_weight": 0.1,
#         "margin": 1.0,
#         "sample_ratio": 0.3,
#         "distance_type": "euclidean"
#       },
#       "adversarial": {
#         "enabled": true,
#         "warmup_epochs": 5,
#         "perturbation_scale": 0.1,
#         "parameter_noise": true,
#         "trajectory_noise": true,
#         "weight": 0.3
#       }
#     },
#     "training": {
#       "batch_size": 32,
#       "num_epochs": 100,
#       "gradient_clipping": 1.0,
#       "gradient_accumulation_steps": 1,
#       "mixed_precision": false,
#       "optimizer": {
#         "type": "adamw",
#         "learning_rate": 0.0005,
#         "weight_decay": 0.0001,
#         "betas": [
#           0.9,
#           0.999
#         ],
#         "eps": 1e-08,
#         "momentum": 0.9,
#         "nesterov": true
#       },
#       "scheduler": {
#         "type": "cosine",
#         "T_max": 100,
#         "eta_min": 1e-06,
#         "step_size": 30,
#         "gamma": 0.1,
#         "patience": 10,
#         "factor": 0.5,
#         "min_lr": 1e-07,
#         "warmup_epochs": 5,
#         "warmup_start_lr": 1e-06
#       },
#       "early_stopping": {
#         "enabled": true,
#         "patience": 30,
#         "min_delta": 0.001,
#         "monitor": "val_accuracy",
#         "mode": "max"
#       },
#       "checkpoint": {
#         "save_best_only": true,
#         "save_frequency": 10,
#         "max_to_keep": 3
#       }
#     },
#     "evaluation": {
#       "metrics": [
#         "accuracy",
#         "top5_accuracy",
#         "eer",
#         "dcf"
#       ],
#       "eval_frequency": 1,
#       "visualization": {
#         "enabled": true,
#         "plot_confusion_matrix": true,
#         "plot_embeddings": true,
#         "plot_attractors": true
#       }
#     },
#     "logging": {
#       "level": "INFO",
#       "tensorboard": {
#         "enabled": true,
#         "log_dir": "./runs"
#       },
#       "wandb": {
#         "enabled": false,
#         "project": "chaotic-speaker-recognition",
#         "entity": null
#       },
#       "log_frequency": 50
#     },
#     "output": {
#       "base_dir": "./experiments/outputs",
#       "save_predictions": true,
#       "save_embeddings": true,
#       "save_analysis": true
#     },
#     "hardware": {
#       "device": "auto",
#       "seed": 42,
#       "deterministic": false,
#       "benchmark": true
#     },
#     "presets": {
#       "fast_debug": {
#         "training": {
#           "batch_size": 8,
#           "num_epochs": 5
#         },
#         "model": {
#           "speaker_embedding": {
#             "hidden_dims": [
#               128,
#               64
#             ]
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": false
#           },
#           "synchronization": {
#             "enabled": false
#           }
#         }
#       },
#       "baseline": {
#         "model": {
#           "classifier": {
#             "type": "linear"
#           }
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": false
#           }
#         }
#       },
#       "high_performance": {
#         "model": {
#           "speaker_embedding": {
#             "dim": 512,
#             "hidden_dims": [
#               1024,
#               512,
#               256
#             ]
#           },
#           "classifier": {
#             "type": "cosine"
#           }
#         },
#         "training": {
#           "num_epochs": 200,
#           "batch_size": 64
#         },
#         "loss": {
#           "stability": {
#             "enabled": true
#           },
#           "synchronization": {
#             "enabled": false
#           },
#           "adversarial": {
#             "enabled": true,
#             "warmup_epochs": 10
#           }
#         }
#       },
#       "robust": {
#         "model": {
#           "chaotic_embedding": {
#             "noise_level": 0.01
#           }
#         },
#         "loss": {
#           "adversarial": {
#             "enabled": true,
#             "perturbation_scale": 0.15,
#             "warmup_epochs": 3
#           }
#         },
#         "audio": {
#           "augmentation": {
#             "enabled": true,
#             "noise_injection": 0.01
#           }
#         }
#       }
#     }
#   },
#   "num_speakers": 251,
#   "model_type": "full_chaotic",
#   "embedding_dim": 10,
#   "delay_method": "autocorr",
#   "mlsa_scales": 5,
#   "rqa_radius_ratio": 0.1,
#   "chaotic_system": "lorenz",
#   "evolution_time": 0.5,
#   "time_step": 0.01,
#   "coupling_strength": 1.0,
#   "noise_level": 0.001,
#   "pooling_type": "comprehensive",
#   "speaker_embedding_dim": 256,
#   "embedding_hidden_dims": [
#     512,
#     256,
#     128
#   ],
#   "classifier_type": "cosine",
#   "temperature": 30.0,
#   "margin": 0.35,
#   "batch_size": 32,
#   "num_epochs": 100,
#   "learning_rate": 0.0005,
#   "weight_decay": 0.0001,
#   "gradient_clipping": 1.0,
#   "optimizer": {
#     "type": "adamw",
#     "params": {
#       "betas": [
#         0.9,
#         0.999
#       ],
#       "eps": 1e-08,
#       "weight_decay": 0.0001
#     }
#   },
#   "scheduler": {
#     "type": "cosine",
#     "params": {
#       "T_max": 100,
#       "eta_min": 1e-06
#     }
#   },
#   "early_stopping": {
#     "patience": 30
#   },
#   "sample_rate": 16000,
#   "max_audio_length": 3.0,
#   "frame_length": 400,
#   "hop_length": 160,
#   "data_dir": "/scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2",
#   "device": "auto",
#   "seed": 42,
#   "loss_config": {
#     "classification": {
#       "type": "cross_entropy",
#       "label_smoothing": 0.0
#     },
#     "stability": {
#       "enabled": true,
#       "weight": 0.1,
#       "target_lyapunov_range": [
#         0.1,
#         2.0
#       ],
#       "trajectory_bound": 50.0,
#       "collapse_threshold": 0.1,
#       "diversity_weight": 0.05
#     },
#     "synchronization": {
#       "enabled": false,
#       "sync_weight": 0.1,
#       "desync_weight": 0.1,
#       "margin": 1.0,
#       "sample_ratio": 0.3,
#       "distance_type": "euclidean"
#     },
#     "adversarial": {
#       "enabled": true,
#       "warmup_epochs": 5,
#       "perturbation_scale": 0.1,
#       "parameter_noise": true,
#       "trajectory_noise": true,
#       "weight": 0.3
#     }
#   },
#   "optional_modules": {
#     "bifurcation_control": {
#       "enabled": false
#     },
#     "differentiable_features": {
#       "enabled": true,
#       "lyapunov_dim": 8,
#       "rqa_dim": 6,
#       "additional_stats": true
#     }
#   },
#   "epochs": 100,
#   "optimize_parameters": true
# }
# 2026-02-23 09:38:18,785 - chaotic_trainer - INFO - System info: {'platform': 'Linux-4.18.0-553.74.1.el8_10.x86_64-x86_64-with-glibc2.28', 'system': 'Linux', 'node': 'g1102.mahti.csc.fi', 'release': '4.18.0-553.74.1.el8_10.x86_64', 'version': '#1 SMP Sun Sep 7 09:23:35 EDT 2025', 'machine': 'x86_64', 'processor': 'x86_64', 'python_version': '3.12.10 (main, Jun  3 2025, 21:04:06) [GCC 8.5.0 20210514 (Red Hat 8.5.0-26)]', 'python_executable': '/usr/bin/python', 'cpu_count': 256, 'total_memory': 540285169664, 'available_memory': 512637870080, 'gpu_info': {'cuda_available': True, 'cuda_version': '12.6', 'gpu_count': 1, 'gpu_names': ['NVIDIA A100-SXM4-40GB MIG 1g.5gb']}, 'package_versions': {'numpy': '1.26.4', 'scipy': '1.13.1', 'scikit-learn': 'not installed', 'librosa': '0.11.0', 'soundfile': '0.13.1', 'torch': '2.7.1+cu126', 'tensorflow': 'not installed', 'matplotlib': '3.10.3', 'pandas': '2.3.0'}, 'git_info': {'commit_hash': '1b9376c7b52fe7c8cb3d9e6e9552896e57f82a52', 'branch': 'origin', 'is_dirty': True}}
# INFO:chaotic_trainer:System info: {'platform': 'Linux-4.18.0-553.74.1.el8_10.x86_64-x86_64-with-glibc2.28', 'system': 'Linux', 'node': 'g1102.mahti.csc.fi', 'release': '4.18.0-553.74.1.el8_10.x86_64', 'version': '#1 SMP Sun Sep 7 09:23:35 EDT 2025', 'machine': 'x86_64', 'processor': 'x86_64', 'python_version': '3.12.10 (main, Jun  3 2025, 21:04:06) [GCC 8.5.0 20210514 (Red Hat 8.5.0-26)]', 'python_executable': '/usr/bin/python', 'cpu_count': 256, 'total_memory': 540285169664, 'available_memory': 512637870080, 'gpu_info': {'cuda_available': True, 'cuda_version': '12.6', 'gpu_count': 1, 'gpu_names': ['NVIDIA A100-SXM4-40GB MIG 1g.5gb']}, 'package_versions': {'numpy': '1.26.4', 'scipy': '1.13.1', 'scikit-learn': 'not installed', 'librosa': '0.11.0', 'soundfile': '0.13.1', 'torch': '2.7.1+cu126', 'tensorflow': 'not installed', 'matplotlib': '3.10.3', 'pandas': '2.3.0'}, 'git_info': {'commit_hash': '1b9376c7b52fe7c8cb3d9e6e9552896e57f82a52', 'branch': 'origin', 'is_dirty': True}}
# Starting chaotic neural network training...
# Systems: ['lorenz']
# Model types: ['full_chaotic']
# Runs per configuration: 1
# 2026-02-23 09:38:18,785 - chaotic_trainer - INFO - Training 1 systems × 1 types × 1 runs...
# INFO:chaotic_trainer:Training 1 systems × 1 types × 1 runs...
# 2026-02-23 09:38:18,785 - chaotic_trainer - INFO - Systems: ['lorenz']
# INFO:chaotic_trainer:Systems: ['lorenz']
# 2026-02-23 09:38:18,785 - chaotic_trainer - INFO - Model types: ['full_chaotic']
# INFO:chaotic_trainer:Model types: ['full_chaotic']
# 2026-02-23 09:38:18,785 - chaotic_trainer - INFO -
# ============================================================
# INFO:chaotic_trainer:
# ============================================================
# 2026-02-23 09:38:18,786 - chaotic_trainer - INFO - TRAINING: LORENZ + FULL_CHAOTIC
# INFO:chaotic_trainer:TRAINING: LORENZ + FULL_CHAOTIC
# 2026-02-23 09:38:18,786 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================
# 2026-02-23 09:38:18,786 - chaotic_trainer - INFO - Training chaotic_lorenz_full_chaotic_run_0...
# INFO:chaotic_trainer:Training chaotic_lorenz_full_chaotic_run_0...
# 2026-02-23 09:38:18,786 - chaotic_trainer - INFO - Optimizing parameters for lorenz system...
# INFO:chaotic_trainer:Optimizing parameters for lorenz system...
# CheckpointManager initialized for experiment: exp_20260223_093818
# Checkpoint directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_093818
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Environment information collected
# [2026-02-23 09:38:18] [INFO] Configuring deterministic operations
# [2026-02-23 09:38:18] [INFO] PyTorch deterministic operations configured
# [2026-02-23 09:38:18] [INFO] Starting reproducibility verification
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 1 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 2 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 3 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 4 is reproducible
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Setting global random seed to: 42
# [2026-02-23 09:38:18] [INFO] Python random seed set
# [2026-02-23 09:38:18] [INFO] PYTHONHASHSEED set to: 42
# [2026-02-23 09:38:18] [INFO] NumPy random seed set
# [2026-02-23 09:38:18] [INFO] PyTorch CUDA seeds set
# [2026-02-23 09:38:18] [INFO] PyTorch strict reproducibility mode enabled
# [2026-02-23 09:38:18] [INFO] PyTorch seeds set
# [2026-02-23 09:38:18] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2026-02-23 09:38:18] [INFO] Operation 5 is reproducible
# [2026-02-23 09:38:18] [SUCCESS] All operations are reproducible
#
# ============================================================
# REPRODUCIBILITY SUMMARY
# ============================================================
# Seed: 42
# Strict Mode: True
# Environment Hash: 1a6c61f1d1667d7a
# Python Version: 3.12.10
#
# Available Libraries:
#   numpy: 1.26.4
#   torch: 2.7.1+cu126
#   cuda_version: 12.6
#   cudnn_version: 91002
#   librosa: 0.11.0
#   soundfile: 0.13.1
#
# Environment Variables:
#   PYTHONHASHSEED: 42
#   CUDA_VISIBLE_DEVICES: MIG-24ae1daa-9c0a-5c0f-bbc1-bacbeac9256d
#   OMP_NUM_THREADS: 1
#   MKL_NUM_THREADS: 1
# ============================================================
# 2026-02-23 09:38:18,796 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Initialized experiment: chaotic_lorenz_full_chaotic_run_0
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Initialized experiment: chaotic_lorenz_full_chaotic_run_0
# 2026-02-23 09:38:18,815 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Device: cuda
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Device: cuda
# 2026-02-23 09:38:18,815 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Output directory: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0
# 2026-02-23 09:38:18,815 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Initialized chaotic network experiment with lorenz system
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Initialized chaotic network experiment with lorenz system
# 2026-02-23 09:38:18,815 - chaotic_trainer - INFO - Setting up chaotic_lorenz_full_chaotic_run_0...
# INFO:chaotic_trainer:Setting up chaotic_lorenz_full_chaotic_run_0...
# 2026-02-23 09:38:18,815 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Setting up experiment components...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Setting up experiment components...
# 2026-02-23 09:38:18,815 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating dataloaders...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating dataloaders...
# ====================
# Trying to load dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# ====================
# Loading LibriSpeech dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Dataset validation: 0 speakers, 0 files
# Loading subsets: ['7976', '1988', '8297', '5895', '3000', '5694', '1462', '1272', '777', '84', '6295', '3536', '2803', '3576', '8842', '7850', '2035', '2412', '3752', '251', '174', '5338', '6241', '2428', '6319', '1993']
# Created label mapping for 26 speakers: labels in [0, 25]
# Dataset loaded: 679 samples from 26 speakers
# Split dataset with train: 472 sample, 26 speakers
# Split dataset with val: 89 sample, 26 speakers
# Split dataset with test: 118 sample, 26 speakers
# 2026-02-23 09:38:19,198 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Detected 26 speakers in dataset
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Detected 26 speakers in dataset
# 2026-02-23 09:38:19,198 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Dataloaders created:
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Dataloaders created:
# 2026-02-23 09:38:19,198 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Train: 14 batches
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Train: 14 batches
# 2026-02-23 09:38:19,198 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Val: 3 batches
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Val: 3 batches
# 2026-02-23 09:38:19,198 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Test: 4 batches
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Test: 4 batches
# 2026-02-23 09:38:19,199 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating model...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating model...
# 2026-02-23 09:38:19,199 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Using actual num_speakers from dataset: 26
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Using actual num_speakers from dataset: 26
# [CONFIG DEBUG] Phase space: dim=10, delay_method=autocorr, dimension_method=false_neighbors
# Chaotic feature dimensions: MLSA=105, RQA=125, Total=230
# [NETWORK DEBUG] ChaoticEmbedding created with:
#   use_bifurcation_control=False
#   bifurcation_net exists: False
# [INIT] Registered diff_feat_projection: 270 -> 230
# [GRADIENT FIX] Differentiable chaos features enabled: output_dim=270
# [GRADIENT FIX] Added differentiable raw audio path
#
# ============================================================
# ENHANCED CHAOTIC NETWORK INITIALIZED
# ============================================================
# Total parameters: 584,959
# Parameters per speaker: 22498
# Speaker embedding dim: 256
# Hidden dims: [512, 256, 128]
# ============================================================
#
# 2026-02-23 09:39:25,908 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Total parameters: 584,959
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Total parameters: 584,959
# 2026-02-23 09:39:25,908 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Trainable parameters: 584,959
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Trainable parameters: 584,959
# 2026-02-23 09:39:25,908 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating optimizer...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating optimizer...
# 2026-02-23 09:39:27,015 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Optimizer: AdamW
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Optimizer: AdamW
# 2026-02-23 09:39:27,015 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating scheduler...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating scheduler...
# 2026-02-23 09:39:27,015 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Scheduler: CosineAnnealingLR
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Scheduler: CosineAnnealingLR
# 2026-02-23 09:39:27,016 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating criterion...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating criterion...
# 2026-02-23 09:39:27,016 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Criterion: CrossEntropyLoss
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Criterion: CrossEntropyLoss
# 2026-02-23 09:39:27,087 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Configuration saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0/config.json
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Configuration saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0/config.json
# 2026-02-23 09:39:27,087 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Experiment setup completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Experiment setup completed
# 2026-02-23 09:39:27,087 - chaotic_trainer - INFO - 🚀 No checkpoint specified, starting from scratch
# INFO:chaotic_trainer:🚀 No checkpoint specified, starting from scratch
# 2026-02-23 09:39:27,088 - chaotic_trainer - INFO - Model parameters: 584,959 (trainable: 584,959)
# INFO:chaotic_trainer:Model parameters: 584,959 (trainable: 584,959)
# 2026-02-23 09:39:27,088 - chaotic_trainer - INFO - Training with chaotic dynamics monitoring...
# INFO:chaotic_trainer:Training with chaotic dynamics monitoring...
# 2026-02-23 09:39:27,088 - chaotic_trainer - INFO - Starting training from epoch 0 for 100 more epochs...
# INFO:chaotic_trainer:Starting training from epoch 0 for 100 more epochs...
# 2026-02-23 09:39:27,088 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Starting training for 100 epochs
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Starting training for 100 epochs
# 2026-02-23 09:39:27,226 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -
# ================================================================================
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:
# ================================================================================
# 2026-02-23 09:39:27,226 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - COMPREHENSIVE DEBUG - FIRST BATCH
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:COMPREHENSIVE DEBUG - FIRST BATCH
# 2026-02-23 09:39:27,226 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - ================================================================================
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:================================================================================
# 2026-02-23 09:39:27,227 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Batch Info:
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Batch Info:
# 2026-02-23 09:39:27,227 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Audio shape: torch.Size([32, 48000])
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Audio shape: torch.Size([32, 48000])
# 2026-02-23 09:39:27,227 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Targets shape: torch.Size([32])
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Targets shape: torch.Size([32])
# 2026-02-23 09:39:27,231 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   Targets (first 8): tensor([23, 10, 24, 14,  5, 17,  8,  0], device='cuda:0')
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  Targets (first 8): tensor([23, 10, 24, 14,  5, 17,  8,  0], device='cuda:0')
# 2026-02-23 09:39:27,798 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - ================================================================================
#
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:================================================================================
#
# 2026-02-23 09:39:27,799 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - [ADVERSARIAL] Initialized AdversarialChaoticAugmentation
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:[ADVERSARIAL] Initialized AdversarialChaoticAugmentation
# 2026-02-23 09:39:27,936 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - [STABILITY] Initialized LyapunovStabilityLoss
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] Initialized LyapunovStabilityLoss
# 2026-02-23 09:39:27,942 - experiment_chaotic_lorenz_full_chaotic_run_0 - DEBUG - [STABILITY] lyap=0.091, max_norm=46.0, min_std=0.016
# DEBUG:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] lyap=0.091, max_norm=46.0, min_std=0.016
# 2026-02-23 09:39:28,599 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 0: [0/472 (0.0%)]	Loss: 4.856831
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 0: [0/472 (0.0%)]	Loss: 4.856831
# 2026-02-23 09:39:34,130 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 0: Train Loss: 4.7100, Train Acc: 0.0246, Val Loss: 4.1377, Val Acc: 0.0225
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 0: Train Loss: 4.7100, Train Acc: 0.0246, Val Loss: 4.1377, Val Acc: 0.0225
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_093818/checkpoint_epoch_0000.pt
# ...
# 2026-02-23 09:48:24,042 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 81: [0/472 (0.0%)]	Loss: 0.041645
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 81: [0/472 (0.0%)]	Loss: 0.041645
# 2026-02-23 09:48:30,028 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 81: Train Loss: 0.0508, Train Acc: 0.9933, Val Loss: 0.1362, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 81: Train Loss: 0.0508, Train Acc: 0.9933, Val Loss: 0.1362, Val Acc: 0.9663
# 2026-02-23 09:48:30,593 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 82: [0/472 (0.0%)]	Loss: 0.020801
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 82: [0/472 (0.0%)]	Loss: 0.020801
# 2026-02-23 09:48:36,799 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 82: Train Loss: 0.0370, Train Acc: 0.9955, Val Loss: 0.0742, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 82: Train Loss: 0.0370, Train Acc: 0.9955, Val Loss: 0.0742, Val Acc: 0.9775
# 2026-02-23 09:48:37,365 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 83: [0/472 (0.0%)]	Loss: 0.033063
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 83: [0/472 (0.0%)]	Loss: 0.033063
# 2026-02-23 09:48:43,399 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 83: Train Loss: 0.0481, Train Acc: 0.9955, Val Loss: 0.0834, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 83: Train Loss: 0.0481, Train Acc: 0.9955, Val Loss: 0.0834, Val Acc: 0.9663
# 2026-02-23 09:48:43,950 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 84: [0/472 (0.0%)]	Loss: 0.024113
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 84: [0/472 (0.0%)]	Loss: 0.024113
# 2026-02-23 09:48:49,900 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 84: Train Loss: 0.0395, Train Acc: 0.9978, Val Loss: 0.0836, Val Acc: 0.9551
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 84: Train Loss: 0.0395, Train Acc: 0.9978, Val Loss: 0.0836, Val Acc: 0.9551
# 2026-02-23 09:48:50,477 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 85: [0/472 (0.0%)]	Loss: 0.115279
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 85: [0/472 (0.0%)]	Loss: 0.115279
# 2026-02-23 09:48:53,810 - experiment_chaotic_lorenz_full_chaotic_run_0 - DEBUG - [STABILITY] lyap=0.014, max_norm=49.6, min_std=11.259
# DEBUG:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] lyap=0.014, max_norm=49.6, min_std=11.259
# 2026-02-23 09:48:56,458 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 85: Train Loss: 0.0428, Train Acc: 0.9955, Val Loss: 0.0879, Val Acc: 0.9551
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 85: Train Loss: 0.0428, Train Acc: 0.9955, Val Loss: 0.0879, Val Acc: 0.9551
# 2026-02-23 09:48:57,022 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 86: [0/472 (0.0%)]	Loss: 0.030326
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 86: [0/472 (0.0%)]	Loss: 0.030326
# 2026-02-23 09:49:03,019 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 86: Train Loss: 0.0326, Train Acc: 0.9955, Val Loss: 0.0993, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 86: Train Loss: 0.0326, Train Acc: 0.9955, Val Loss: 0.0993, Val Acc: 0.9663
# 2026-02-23 09:49:03,592 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 87: [0/472 (0.0%)]	Loss: 0.047796
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 87: [0/472 (0.0%)]	Loss: 0.047796
# 2026-02-23 09:49:09,595 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 87: Train Loss: 0.0325, Train Acc: 0.9955, Val Loss: 0.0778, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 87: Train Loss: 0.0325, Train Acc: 0.9955, Val Loss: 0.0778, Val Acc: 0.9775
# 2026-02-23 09:49:10,155 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 88: [0/472 (0.0%)]	Loss: 0.042568
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 88: [0/472 (0.0%)]	Loss: 0.042568
# 2026-02-23 09:49:16,190 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 88: Train Loss: 0.0610, Train Acc: 0.9888, Val Loss: 0.0980, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 88: Train Loss: 0.0610, Train Acc: 0.9888, Val Loss: 0.0980, Val Acc: 0.9775
# 2026-02-23 09:49:16,752 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 89: [0/472 (0.0%)]	Loss: 0.031845
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 89: [0/472 (0.0%)]	Loss: 0.031845
# 2026-02-23 09:49:22,714 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 89: Train Loss: 0.0293, Train Acc: 0.9978, Val Loss: 0.1054, Val Acc: 0.9551
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 89: Train Loss: 0.0293, Train Acc: 0.9978, Val Loss: 0.1054, Val Acc: 0.9551
# 2026-02-23 09:49:23,276 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 90: [0/472 (0.0%)]	Loss: 0.038007
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 90: [0/472 (0.0%)]	Loss: 0.038007
# 2026-02-23 09:49:29,292 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 90: Train Loss: 0.0355, Train Acc: 0.9978, Val Loss: 0.0760, Val Acc: 0.9663
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 90: Train Loss: 0.0355, Train Acc: 0.9978, Val Loss: 0.0760, Val Acc: 0.9663
# Removed old checkpoint: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_093818/checkpoint_epoch_0071.pt
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_093818/checkpoint_epoch_0090.pt
# Checkpoint saved: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/experiments/chaotic_lorenz_full_chaotic_run_0/checkpoints/exp_20260223_093818/latest.pt
# 2026-02-23 09:49:29,921 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 91: [0/472 (0.0%)]	Loss: 0.035268
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 91: [0/472 (0.0%)]	Loss: 0.035268
# 2026-02-23 09:49:35,946 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 91: Train Loss: 0.0320, Train Acc: 0.9978, Val Loss: 0.0805, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 91: Train Loss: 0.0320, Train Acc: 0.9978, Val Loss: 0.0805, Val Acc: 0.9775
# 2026-02-23 09:49:36,505 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 92: [0/472 (0.0%)]	Loss: 0.025718
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 92: [0/472 (0.0%)]	Loss: 0.025718
# 2026-02-23 09:49:40,528 - experiment_chaotic_lorenz_full_chaotic_run_0 - DEBUG - [STABILITY] lyap=0.014, max_norm=49.7, min_std=11.259
# DEBUG:experiment_chaotic_lorenz_full_chaotic_run_0:[STABILITY] lyap=0.014, max_norm=49.7, min_std=11.259
# 2026-02-23 09:49:42,439 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 92: Train Loss: 0.0293, Train Acc: 0.9978, Val Loss: 0.0750, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 92: Train Loss: 0.0293, Train Acc: 0.9978, Val Loss: 0.0750, Val Acc: 0.9775
# 2026-02-23 09:49:43,004 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 93: [0/472 (0.0%)]	Loss: 0.035051
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 93: [0/472 (0.0%)]	Loss: 0.035051
# 2026-02-23 09:50:02,109 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 95: Train Loss: 0.0277, Train Acc: 1.0000, Val Loss: 0.0860, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 95: Train Loss: 0.0277, Train Acc: 1.0000, Val Loss: 0.0860, Val Acc: 0.9775
# 2026-02-23 09:50:02,670 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 96: [0/472 (0.0%)]	Loss: 0.077181
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 96: [0/472 (0.0%)]	Loss: 0.077181
# 2026-02-23 09:50:08,691 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 96: Train Loss: 0.0412, Train Acc: 0.9933, Val Loss: 0.0747, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 96: Train Loss: 0.0412, Train Acc: 0.9933, Val Loss: 0.0747, Val Acc: 0.9775
# 2026-02-23 09:50:09,262 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 97: [0/472 (0.0%)]	Loss: 0.124217
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 97: [0/472 (0.0%)]	Loss: 0.124217
# 2026-02-23 09:50:15,329 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 97: Train Loss: 0.0470, Train Acc: 0.9911, Val Loss: 0.0786, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 97: Train Loss: 0.0470, Train Acc: 0.9911, Val Loss: 0.0786, Val Acc: 0.9775
# 2026-02-23 09:50:15,897 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 98: [0/472 (0.0%)]	Loss: 0.019426
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 98: [0/472 (0.0%)]	Loss: 0.019426
# 2026-02-23 09:50:21,917 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 98: Train Loss: 0.0323, Train Acc: 0.9955, Val Loss: 0.0760, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 98: Train Loss: 0.0323, Train Acc: 0.9955, Val Loss: 0.0760, Val Acc: 0.9775
# 2026-02-23 09:50:22,481 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Train Epoch 99: [0/472 (0.0%)]	Loss: 0.042638
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Train Epoch 99: [0/472 (0.0%)]	Loss: 0.042638
# 2026-02-23 09:50:28,499 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Epoch 99: Train Loss: 0.0285, Train Acc: 0.9978, Val Loss: 0.0797, Val Acc: 0.9775
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Epoch 99: Train Loss: 0.0285, Train Acc: 0.9978, Val Loss: 0.0797, Val Acc: 0.9775
# 2026-02-23 09:50:28,505 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Running final test evaluation...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Running final test evaluation...
# 2026-02-23 09:50:29,281 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Test Results:
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Test Results:
# 2026-02-23 09:50:29,281 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   loss: 0.1247
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  loss: 0.1247
# 2026-02-23 09:50:29,281 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   accuracy: 0.9407
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  accuracy: 0.9407
# 2026-02-23 09:50:29,282 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   avg_confidence: 0.6812
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  avg_confidence: 0.6812
# 2026-02-23 09:50:29,282 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   embedding_diversity: 0.0610
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  embedding_diversity: 0.0610
# 2026-02-23 09:50:29,282 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   embedding_norm_mean: 1.0000
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  embedding_norm_mean: 1.0000
# 2026-02-23 09:50:29,282 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO -   embedding_norm_std: 0.0000
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:  embedding_norm_std: 0.0000
# 2026-02-23 09:50:29,284 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Training completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Training completed
# 2026-02-23 09:50:29,284 - chaotic_trainer - INFO - Evaluating chaotic_lorenz_full_chaotic_run_0...
# INFO:chaotic_trainer:Evaluating chaotic_lorenz_full_chaotic_run_0...
# 2026-02-23 09:50:30,051 - chaotic_trainer - INFO - Running chaotic analysis...
# INFO:chaotic_trainer:Running chaotic analysis...
# 2026-02-23 09:50:30,051 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Running comprehensive chaotic network analysis...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Running comprehensive chaotic network analysis...
# 2026-02-23 09:50:30,051 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Analyzing chaotic features and dynamics...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Analyzing chaotic features and dynamics...
# 2026-02-23 09:50:30,715 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Chaotic analysis completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Chaotic analysis completed
# 2026-02-23 09:50:30,716 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Creating chaotic dynamics visualizations...
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Creating chaotic dynamics visualizations...
# 2026-02-23 09:50:33,039 - experiment_chaotic_lorenz_full_chaotic_run_0 - WARNING - Embedding plotting failed: boolean index did not match indexed array along dimension 0; dimension is 8 but corresponding boolean dimension is 32
# WARNING:experiment_chaotic_lorenz_full_chaotic_run_0:Embedding plotting failed: boolean index did not match indexed array along dimension 0; dimension is 8 but corresponding boolean dimension is 32
# 2026-02-23 09:50:33,053 - experiment_chaotic_lorenz_full_chaotic_run_0 - INFO - Chaotic network analysis completed
# INFO:experiment_chaotic_lorenz_full_chaotic_run_0:Chaotic network analysis completed
# 2026-02-23 09:50:33,053 - chaotic_trainer - INFO - Completed chaotic_lorenz_full_chaotic_run_0: Accuracy: 0.9407, Loss: 0.1247, Time: 730.5s
# INFO:chaotic_trainer:Completed chaotic_lorenz_full_chaotic_run_0: Accuracy: 0.9407, Loss: 0.1247, Time: 730.5s
# 2026-02-23 09:50:33,062 - chaotic_trainer - INFO - Progress: 1/1 (100.0%)
# INFO:chaotic_trainer:Progress: 1/1 (100.0%)
# 2026-02-23 09:50:33,062 - chaotic_trainer - INFO - lorenz + full_chaotic Summary: 0.9407 ± 0.0000
# INFO:chaotic_trainer:lorenz + full_chaotic Summary: 0.9407 ± 0.0000
# 2026-02-23 09:50:33,062 - chaotic_trainer - INFO - Analyzing chaotic training results...
# INFO:chaotic_trainer:Analyzing chaotic training results...
# 2026-02-23 09:50:33,064 - chaotic_trainer - INFO - Generating comprehensive chaotic training report...
# INFO:chaotic_trainer:Generating comprehensive chaotic training report...
# 2026-02-23 09:50:34,850 - chaotic_trainer - INFO - Visualizations saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/visualizations
# INFO:chaotic_trainer:Visualizations saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/visualizations
# 2026-02-23 09:50:34,850 - chaotic_trainer - INFO - Reports generated:
# INFO:chaotic_trainer:Reports generated:
# 2026-02-23 09:50:34,850 - chaotic_trainer - INFO -   Text report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/chaotic_training_report.txt
# INFO:chaotic_trainer:  Text report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/chaotic_training_report.txt
# 2026-02-23 09:50:34,851 - chaotic_trainer - INFO -   JSON report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/chaotic_training_results.json
# INFO:chaotic_trainer:  JSON report: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off/chaotic_training_results.json
#
# ============================================================
# CHAOTIC TRAINING COMPLETED
# ============================================================
# Best configuration: lorenz + full_chaotic
# Best accuracy: 0.9407
#
# Systems performance:
#   lorenz: 0.9407 ± 0.0000
# Results saved to: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/Off
# 2026-02-23 09:50:34,851 - chaotic_trainer - INFO - Chaotic training completed.
# INFO:chaotic_trainer:Chaotic training completed.
# 2026-02-23 09:50:34,851 - chaotic_trainer - INFO - ============================================================
# INFO:chaotic_trainer:============================================================
