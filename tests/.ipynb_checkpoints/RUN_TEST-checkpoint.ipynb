# %%
# !python test_chaos_utils.py
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 100
# span=(0.0, 1.0), dt=0.05: expected 21, got 100
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 100
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
# Running Fixed Chaos Utils Tests...
# ...
# ✓ chaos_utils module imported successfully
# test_chen_equations (__main__.TestChaoticSystems.test_chen_equations)
# Test Chen system differential equations. ... ok
# test_chen_system_creation (__main__.TestChaoticSystems.test_chen_system_creation)
# Test Chen system creation and basic properties. ... ok
# test_create_chaotic_system_factory (__main__.TestChaoticSystems.test_create_chaotic_system_factory)
# ...

# %%
# !python test_chaotic_features.py
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 100
# span=(0.0, 1.0), dt=0.05: expected 21, got 100
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 100
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
# /scratch/project_2003370/yueyao/Model/core/mlsa_extractor.py:43: UserWarning: Failed to import required modules: No module named 'core.utils'
#   warnings.warn(f"Failed to import required modules: {e}")
# /scratch/project_2003370/yueyao/Model/core/rqa_extractor.py:38: UserWarning: Failed to import required modules: No module named 'core.utils'
#   warnings.warn(f"Failed to import required modules: {e}")
# Running Chaotic Features Test Suite...
# ...
# ✓ Test data generation available
# ...

# %%
# !python test_mlp_models.py
# Out:
# Running MLP Models Test Suite...
# ...
# ✓ Available backends: PyTorch, Sklearn
# test_custom_hyperparameter_space (__main__.TestHyperparameterOptimization.test_custom_hyperparameter_space)
# Test custom hyperparameter space. ... ok
# test_hyperparameter_grid_generation (__main__.TestHyperparameterOptimization.test_hyperparameter_grid_generation)
# Test hyperparameter grid generation. ... ok
# test_hyperparameter_suggestions (__main__.TestHyperparameterOptimization.test_hyperparameter_suggestions)
# Test hyperparameter suggestions. ... ok
# test_end_to_end_workflow (__main__.TestIntegration.test_end_to_end_workflow)
# Test complete end-to-end workflow. ... Running end-to-end MLP integration test...
# Available models: ['pytorch_mlp', 'sklearn_mlp']
# Testing pytorch_mlp...
#   ✓ pytorch_mlp accuracy: 0.6444
# Testing sklearn_mlp...
# ...

# %%
# !python test_chaotic_models.py
# Out:
# ...
#
# ...
# Running TestChaoticEmbedding
# ...
# test_adaptive_chaotic_embedding (__main__.TestChaoticEmbedding.test_adaptive_chaotic_embedding)
# Test AdaptiveChaoticEmbedding with learnable parameters. ... ok
# test_chaotic_embedding_creation (__main__.TestChaoticEmbedding.test_chaotic_embedding_creation)
# Test ChaoticEmbedding layer creation. ... ok
# test_chaotic_embedding_forward_pass (__main__.TestChaoticEmbedding.test_chaotic_embedding_forward_pass)
# Test forward pass through ChaoticEmbedding. ... ok
# test_different_chaotic_systems (__main__.TestChaoticEmbedding.test_different_chaotic_systems)
# Test different chaotic systems. ... ok
# test_gradient_flow (__main__.TestChaoticEmbedding.test_gradient_flow)
# Test gradient flow through ChaoticEmbedding. ... ok
# test_numerical_stability (__main__.TestChaoticEmbedding.test_numerical_stability)
# Test numerical stability with extreme inputs. ... ok
#
# ----------------------------------------------------------------------
# ...
