# %%
# !python 3D_phasespace_trajectory.py
# Out:
# Generating Multi-Speaker Phase Space Attractor Comparison...
# ...
# Figure saved successfully!
#   - PNG: figure_output/speaker_attractor_comparison.png
#   - PDF: figure_output/speaker_attractor_comparison.pdf
# Figure(2100x1050)
# 2D projection figure saved!
# Figure(1950x1200)
# ...
# All figures generated successfully!

# %%
# !python four_chaotic_attractors.py
# Out:
# ...
# Chaotic Systems Visualization
# ...
# Generating Lorenz attractor...
# Generating Rossler attractor...
# Saved: figure_output/lorenz_rossler_attractors.png/pdf
# Generating Mackey-Glass attractor...
# Generating Chua attractor...
# Saved: figure_output/mackeyglass_chua_attractors.png/pdf
#
# Done!

# %%
# !python RQA.py
# Out:
# Figure(1500x1350)
# Figure saved as rqa_comparison.png and rqa_comparison.pdf

# %%
# !python feature_extraction_pipeline.py
# Out:
# Signal waveform saved as:
#   - signal_waveform.pdf
#   - signal_waveform.png
# Traceback (most recent call last):
#   File "/scratch/project_2003370/yueyao/Model/visualization/chapter2/feature_extraction_pipeline.py", line 214, in <module>
#     mi_values = compute_mutual_information(wave, max_lag=max_lag)
#                                            ^^^^
# NameError: name 'wave' is not defined. Did you forget to import 'wave'?
