# %%
# !python 4.3_chaotic_embedding_architecture.py
# Out:
# /scratch/project_2003370/yueyao/Model/visualization/chapter4/4.3_chaotic_embedding_architecture.py:109: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Figure saved to:
#   - chaotic_embedding_architecture.pdf
#   - chaotic_embedding_architecture.png
# Figure(2100x1500)

# %%
# !python mutual_information.py
# Out:
# Signal waveform saved as:
#   - signal_waveform.pdf
#   - signal_waveform.png
#
# Mutual Information and FNN analysis saved as:
#   - mutual_information_fnn.pdf
#   - mutual_information_fnn.png
# Figure(1600x300)
# Figure(1200x450)
#
# ...
# ANALYSIS SUMMARY
# ...
# Signal length: 200 samples
# Recommended time delay (tau): 4 samples
# Recommended embedding dimension (d): 2
# Mutual information at tau=4: 3.5565 bits
# FNN percentage at d=2: 0.00%
# ...

# %%
# !python thesis_visualizations.py
# Out:
# Generating thesis defense visualizations...
# ...
# Saved: fig1_speaker_attractors.png/pdf
# Saved: fig2_bifurcation_effect.png/pdf
# Saved: fig3_ablation_results.png/pdf
# Saved: fig4_training_curves.png/pdf
# Saved: fig5_regime_distribution.png/pdf
# Saved: fig6_component_contribution.png/pdf
# /scratch/project_2003370/yueyao/Model/visualization/chapter4/thesis_visualizations.py:475: UserWarning: Glyph 10003 (\N{CHECK MARK}) missing from font(s) Helvetica.
#   plt.savefig('fig7_results_table.png', dpi=300, bbox_inches='tight')
# /scratch/project_2003370/yueyao/Model/visualization/chapter4/thesis_visualizations.py:475: UserWarning: Glyph 10007 (\N{BALLOT X}) missing from font(s) Helvetica.
#   plt.savefig('fig7_results_table.png', dpi=300, bbox_inches='tight')
# /scratch/project_2003370/yueyao/Model/visualization/chapter4/thesis_visualizations.py:476: UserWarning: Glyph 10003 (\N{CHECK MARK}) missing from font(s) Helvetica.
#   plt.savefig('fig7_results_table.pdf', bbox_inches='tight')
# ...

# %%
# !python /scratch/project_2003370/yueyao/Model/scripts/precompute_embedding_params_with_plot.py \
    --output params_plot.yaml \
    --n_samples 100 \
    --plot \
    --selected_tau 12 \
    --selected_dim 10 \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Out:
# ...
# EMBEDDING PARAMETER PRECOMPUTATION
# ...
# Data directory: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Number of samples: 100
# Method: mutual_info
#
# Loading 100 audio files...
# Loading audio: 100%|██████████████████████████| 100/100 [00:02<00:00, 40.79it/s]
# Loaded 100 valid audio samples
#
# Estimating parameters...
# Processing: 100%|█████████████████████████████| 100/100 [00:19<00:00,  5.04it/s]
#
# ...
# RESULTS
# ...
#
# Tau (delay) statistics:
#   Mean:   11.78 samples (0.736 ms)
#   Median: 11.00 samples
#   Std:    7.74
#   Range:  [2.0, 45.0]
#
# Dimension statistics:
#   Mean:   3.65
#   Median: 4.00
#   Std:    0.70
#   Range:  [2.0, 4.0]
#
# *** RECOMMENDED VALUES ***
#   fixed_delay: 11
#   embedding_dim: 4
#
# Results saved to: params_plot.yaml
# Raw data saved to: params_plot.json
#
# Generating visualization plots...
# Distribution plot saved: params_plot_distribution.pdf/png
# Combined plot saved: params_plot_combined.pdf/png
#
# ...

# %%
# !python plot_embedding_params.py \
    --json params_plot.json \
    --output embedding_params \
    --selected_tau 12 \
    --selected_dim 10 \
    --combined
# Out:
# Loading data from: params_plot.json
# Loaded 100 tau values and 100 dim values
# Tau stats: mean=11.78, median=11
# Dim stats: mean=3.65, median=4
# Saved: embedding_params_distribution.pdf/png
# Saved: embedding_params_combined.pdf/png
# Saved: embedding_params_heatmap.pdf/png
#
# Done!

# %%
# !python plot_angular_margin.py \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --use_real_data \
    --num_speakers 5 \
    --margin 0.35 \
    --output fig4_angular_margin.pdf
# Out:
#   ⚠ Dataset loader import warning: No module named 'audio_preprocessor'
# ✓ Data package initialized (circular import free)
# ...
# Angular Margin Visualization Generator
# ...
# Using synthetic data for visualization
# Embeddings shape: (150, 3)
# Number of speakers: 5
# Angular margin: 0.35 rad (20.1°)
# Figure saved to: fig4_angular_margin.pdf
# Figure(1400x600)
# Done!

# %%
# !python plot_lr_schedule.py \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2 \
    --epochs 100 \
    --output fig4_lr_schedule.png
# Out:
#   ⚠ Dataset loader import warning: No module named 'audio_preprocessor'
# ✓ Data package initialized (circular import free)
# ...
# Learning Rate Schedule Visualization Generator
# ...
# Epochs: 100
# LR Max: 0.005
# LR Min: 1e-06
#
# Project modules or data not available, using theoretical curve only
# Figure saved to: fig4_lr_schedule.png
# PDF saved to: fig4_lr_schedule.pdf
# Figure(800x500)
#
# Done!
