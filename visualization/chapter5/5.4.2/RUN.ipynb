# %%
# !python gradient_conflict.py
# Out:
# 正在解析日志数据...
# 图像已保存至: figure_5_x_gradient_conflict.png
# Figure(1000x600)

# %%
# !python plot_h1_gradient_conflict.py --log_file training_log.txt --output_dir ./figures
# Out:
# Loading data from log file: training_log.txt
# Extracted 1308 data points from log file
# Saved: h1_conflict_distribution.pdf/png
# Saved: h1_comprehensive_analysis.pdf/png
#
# ...
# H1 GRADIENT CONFLICT ANALYSIS SUMMARY
# ...
# Total batches analyzed: 1308
# Mean conflict ratio: 46.45%
# Std conflict ratio: 29.76%
# Mean cosine similarity: 0.0535
# Batches with >50% conflict: 43.0%
# Batches with <20% conflict: 24.5%
# Batches with >70% conflict: 27.2%
# Correlation (conflict vs cos_sim): -0.9761
# ...
# Saved statistics to: ./figures/h1_statistics.json
