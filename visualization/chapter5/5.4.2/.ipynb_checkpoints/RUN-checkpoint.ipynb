# %%
# !python gradient_conflict.py
# Out:
# 正在解析日志数据...
# 图像已保存至: figure_5_x_gradient_conflict.png
# Figure(1000x600)

# %%
python plot_h1_gradient_conflict.py --json_file h1_data.json --output_dir ./figures
