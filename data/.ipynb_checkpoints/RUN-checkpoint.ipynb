# %%
# !python data_utils.py
# Out:
# Label: speaker1, Valid: True, Errors: []
# Label: invalid speaker, Valid: False, Errors: ['Label contains invalid characters: "invalid speaker"']
# Label: s, Valid: True, Errors: []
# Label: very_long_speaker_name_that_exceeds_limit, Valid: True, Errors: []
# Label: 123, Valid: False, Errors: ["Label must be string, got <class 'int'>"]

# %%
# !python dataset_loader.py
# Out:
# LibriSpeech Chaotic Speaker Recognition Dataset Test
# ...
# Loading LibriSpeech dataset from: ../../dataset/train-clean-100/LibriSpeech/train-clean-100
# /scratch/project_2003370/yueyao/Model/data/dataset_loader.py:200: UserWarning: Dataset validation warnings: ['Dataset must contain at least 2 speakers, found 0']
#   warnings.warn(f"Dataset validation warnings: {validation_result['errors']}")
# ...

# %%
# !python test_data_processing.py
# Out:
# ...
# Running comprehensive data processing tests...
# Available components:
#   - Data utilities: False
#   - Audio preprocessor: True
#   - Dataset loader: False
#   - Audio libraries: True
#   - PyTorch: True
#   - TensorFlow: False
#
# ============================= test session starts ==============================
# platform linux -- Python 3.12.10, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python
# cachedir: .pytest_cache
# rootdir: /scratch/project_2003370/yueyao/Model/data
# plugins: anyio-4.9.0, dash-3.1.0, jaxtyping-0.3.2
# collected 44 items
#
# test_data_processing.py::TestDataValidator::test_is_valid_audio_file_with_valid_extensions SKIPPED [  2%]
# test_data_processing.py::TestDataValidator::test_is_valid_audio_file_with_invalid_extensions SKIPPED [  4%]
# test_data_processing.py::TestDataValidator::test_validate_audio_properties_nonexistent_file SKIPPED [  6%]
# test_data_processing.py::TestDataValidator::test_validate_audio_properties_empty_file SKIPPED [  9%]
# ...
