# %%
# !python train_baselines.py --method mel_mlp --epochs 100
# Out:
# 项目根目录已添加到路径: /scratch/project_2003370/yueyao/Model
# ...
# [2025-09-21 13:04:46] [INFO] Setting global random seed to: 42
# [2025-09-21 13:04:46] [INFO] Python random seed set
# [2025-09-21 13:04:46] [INFO] PYTHONHASHSEED set to: 42
# [2025-09-21 13:04:46] [INFO] NumPy random seed set
# [2025-09-21 13:04:46] [INFO] PyTorch CUDA seeds set
# [2025-09-21 13:04:46] [INFO] PyTorch strict reproducibility mode enabled
# [2025-09-21 13:04:46] [INFO] PyTorch seeds set
# [2025-09-21 13:04:46] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2025-09-21 13:04:46] [INFO] Environment information collected
# [2025-09-21 13:04:46] [INFO] Configuring deterministic operations
# [2025-09-21 13:04:46] [INFO] PyTorch deterministic operations configured
# [2025-09-21 13:04:46] [INFO] Starting reproducibility verification
# [2025-09-21 13:04:46] [INFO] Setting global random seed to: 42
# [2025-09-21 13:04:46] [INFO] Python random seed set
# [2025-09-21 13:04:46] [INFO] PYTHONHASHSEED set to: 42
# ...
