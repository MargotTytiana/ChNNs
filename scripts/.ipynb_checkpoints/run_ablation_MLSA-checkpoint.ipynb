# %%
# !python validate_mlsa_experiment.py
# Out:
# ======================================================================
# MLSA VALIDATION EXPERIMENT
# Testing if Multi-Scale Lyapunov Spectrum Analysis is working
# ======================================================================
#
# ======================================================================
# MLSA (Multi-Scale Lyapunov Spectrum Analysis) VALIDATION
# ======================================================================
#
# This script validates that MLSA is functioning correctly and
# provides useful features for speaker recognition.
#
#
# ============================================================
# EXPERIMENT 1: Basic MLSA Functionality
# ============================================================
#
# Analyzing: lorenz_chaotic (length=2000)
#   Multi-scale LLEs: {'scale_1': 0.0009614624830327591, 'scale_2': 0.002184466844954768, 'scale_4': 0.007028229455137818, 'scale_8': 0.004267399454102061, 'scale_16': 0.0038465174520364753}
#   Mean LLE: 0.0037
#   LLE Range: 0.0061
#
# Analyzing: periodic (length=2000)
#   Multi-scale LLEs: {'scale_1': -2.5155191345045774e-05, 'scale_2': 0.0025108884236565124, 'scale_4': 0.0029989924831167205, 'scale_8': 0.002113437011645895, 'scale_16': 0.00036412142076353894}
#   Mean LLE: 0.0016
#   LLE Range: 0.0030
#
# Analyzing: random_noise (length=2000)
#   Multi-scale LLEs: {'scale_1': -0.00872256736047035, 'scale_2': -0.0005273569332323261, 'scale_4': 0.0037128877162169683, 'scale_8': 0.003849994047365184, 'scale_16': 0.00035862291646469294}
#   Mean LLE: -0.0003
#   LLE Range: 0.0126
#
# Analyzing: speech_like (length=48000)
#   Multi-scale LLEs: {'scale_1': 0.001500343534300412, 'scale_2': 0.00039897327666105345, 'scale_4': 0.0004407513076956961, 'scale_8': -0.001208818617744729, 'scale_16': -5.174685584582971e-05}
#   Mean LLE: 0.0002
#   LLE Range: 0.0027
#
# --- Discrimination Analysis ---
# Chaotic vs Periodic discrimination: 0.0021
#   -> MLSA can distinguish signal types: NO
#
# ============================================================
# EXPERIMENT 2: Speaker Discrimination with MLSA
# ============================================================
#
# Generating Speaker 1: f0=100Hz
#   Mean LLE: 0.0036
#   Intra-speaker variance: 0.000004
#
# Generating Speaker 2: f0=150Hz
#   Mean LLE: 0.0034
#   Intra-speaker variance: 0.000004
#
# Generating Speaker 3: f0=200Hz
#   Mean LLE: 0.0041
#   Intra-speaker variance: 0.000007
#
# Generating Speaker 4: f0=120Hz
#   Mean LLE: 0.0028
#   Intra-speaker variance: 0.000003
#
# Generating Speaker 5: f0=180Hz
#   Mean LLE: 0.0024
#   Intra-speaker variance: 0.000002
#
# --- Speaker Discrimination Analysis ---
# Inter-speaker variance: 0.000000
# Average intra-speaker variance: 0.000004
# Fisher ratio (inter/intra): 0.08
#   -> MLSA discriminates speakers: WEAK
#
# ============================================================
# EXPERIMENT 3: Multi-Scale Analysis Importance
# ============================================================
#
# --- Single-Scale (Scale=1 only) ---
# LLE at scale 1: 0.0015
# Features: 1 value
#
# --- Multi-Scale (Scales 1,2,4,8,16) ---
# LLE at scale_1: 0.0015
# LLE at scale_2: 0.0004
# LLE at scale_4: 0.0004
# LLE at scale_8: -0.0012
# LLE at scale_16: -0.0001
#
# Aggregated features: 6 values
# Mean LLE: 0.0002
# LLE Range across scales: 0.0027
#
# --- Scale-Specific Dynamics ---
# Scale 1 (original):     Captures fast glottal dynamics (~100-200Hz)
# Scale 2-4:              Captures formant transitions (~20-50Hz)
# Scale 8-16:             Captures prosody patterns (~1-5Hz)
#
# Correlation between adjacent scales: 0.164
#   -> Scales provide complementary information
#
# ============================================================
# EXPERIMENT 4: MLSA Robustness to Noise
# ============================================================
# SNR  20dB: Mean LLE = 0.0009
# SNR  10dB: Mean LLE = 0.0013
# SNR   5dB: Mean LLE = 0.0012
# SNR   0dB: Mean LLE = 0.0010
# SNR  -5dB: Mean LLE = 0.0006
#
# --- Feature Stability Analysis ---
# snr_20dB: 328.7% change from clean
# snr_10dB: 490.8% change from clean
# snr_5dB: 446.6% change from clean
# snr_0dB: 353.6% change from clean
# snr_-5dB: 165.6% change from clean
#
# Visualization saved to: mlsa_validation_results.png/pdf
#
# ======================================================================
# VALIDATION COMPLETE
# ======================================================================
# Total time: 61.38 seconds
#
# --------------------------------------------------
# FINAL VERDICT:
# --------------------------------------------------
#   Signal discrimination: ✗ FAIL
#   Multi-scale extraction: ✓ PASS
#   Noise robustness: ✓ PASS
#
# OVERALL: ✗ ISSUES DETECTED
#
# ======================================================================
# EXPERIMENT COMPLETE - Check 'mlsa_validation_results.png' for visualizations
# ======================================================================

# %%
# !python validate_mlsa_real_dataset.py
# Out:
# ======================================================================
# MLSA vs Traditional Features: Real Dataset Validation
# ======================================================================
#
# Using dataset: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
#
# ======================================================================
# REAL DATASET MLSA VALIDATION EXPERIMENT
# Comparing MLSA with Traditional Features on 26-Speaker Dataset
# ======================================================================
#
# [Step 1] Loading Dataset...
# Loading dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Found 1089 FLAC files
# Found 26 speakers
# Loaded 382 audio samples from 26 speakers
#   Loaded 382 samples from 26 speakers
#   Labels distribution: [15 15 15 15 11 15 15 15 15 15 15 15 15 15 15 15 15 15 15 13 15 15 15 14
#  15 14]
#
# [Step 2] Extracting Features...
#
#   Extracting MFCC features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   MFCC: shape=(382, 52), time=2.55s, failed=0
#
#   Extracting Mel features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   Mel: shape=(382, 160), time=1.98s, failed=0
#
#   Extracting MLSA features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   MLSA: shape=(382, 13), time=741.04s, failed=0
#
#   Extracting MFCC+MLSA features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   MFCC+MLSA: shape=(382, 65), time=746.74s, failed=0
#
# [Step 3] Normalizing Features...
#
# [Step 4] Evaluating Feature Quality...
#
#   Evaluating MFCC...
#     Fisher Score:     1.3512
#     Silhouette Score: 0.1740
#     K-NN Accuracy:    94.75%
#     LDA Accuracy:     98.69%
#
#   Evaluating Mel...
#     Fisher Score:     1.2600
#     Silhouette Score: 0.0861
#     K-NN Accuracy:    79.83%
#     LDA Accuracy:     100.00%
#
#   Evaluating MLSA...
#     Fisher Score:     0.8592
#     Silhouette Score: -0.1656
#     K-NN Accuracy:    20.94%
#     LDA Accuracy:     29.60%
#
#   Evaluating MFCC+MLSA...
#     Fisher Score:     1.2330
#     Silhouette Score: 0.1544
#     K-NN Accuracy:    93.20%
#     LDA Accuracy:     97.12%
#
# [Step 5] MLSA-Specific Analysis...
#
#   Speaker LLE Distribution (sorted by mean LLE):
#   --------------------------------------------------
#     Speaker  4: mean_LLE=-0.9729 ± 0.3248
#     Speaker 22: mean_LLE=-0.8335 ± 0.3332
#     Speaker  3: mean_LLE=-0.7747 ± 0.2273
#     Speaker  5: mean_LLE=-0.7733 ± 0.2223
#     Speaker  0: mean_LLE=-0.7148 ± 0.4352
#     ...
#     Speaker  6: mean_LLE=0.6853 ± 0.8150
#     Speaker  7: mean_LLE=0.8580 ± 0.7597
#     Speaker 13: mean_LLE=1.1433 ± 0.5731
#     Speaker 15: mean_LLE=1.1586 ± 1.4994
#     Speaker 18: mean_LLE=1.9607 ± 0.8943
#
# [Step 6] Creating Visualizations...
#   Saved visualization to: /scratch/project_2003370/yueyao/Model/scripts/outputs/mlsa_experiments/mlsa_real_dataset_validation.png
#   Saved results to: /scratch/project_2003370/yueyao/Model/scripts/outputs/mlsa_experiments/mlsa_real_dataset_results.json
#
# ======================================================================
# FINAL RESULTS SUMMARY
# ======================================================================
#
# ----------------------------------------------------------------------
# Feature Type       Dim     Fisher   Silhouette   K-NN Acc    LDA Acc
# ----------------------------------------------------------------------
# MFCC                52     1.3512       0.1740     94.75%     98.69%
# Mel                160     1.2600       0.0861     79.83%    100.00%
# MLSA                13     0.8592      -0.1656     20.94%     29.60%
# MFCC+MLSA           65     1.2330       0.1544     93.20%     97.12%
# ----------------------------------------------------------------------
#
# ======================================================================
# CONCLUSIONS
# ======================================================================
#
# 1. MLSA vs MFCC Comparison:
#    - MFCC K-NN Accuracy:  94.75%
#    - MLSA K-NN Accuracy:  20.94%
#    - Difference:          -73.81%
#
# 2. Combined Features:
#    - MFCC+MLSA Accuracy:  93.20%
#    - Improvement over MFCC: -1.56%
#
# 3. MLSA Contribution:
#    - MLSA provides REDUNDANT information
#    - Fisher Score ratio (MLSA/MFCC): 0.64x
#
# 4. Verdict:
#    - MLSA IS NEEDS TUNING for speaker recognition
#    - ⚠ MLSA may need parameter tuning
#
#
# Total experiment time: 1513.74 seconds
#
# Experiment complete! Check outputs for visualizations.

# %%
# !python validate_mlsa_real_dataset.py
# Out:
# ======================================================================
# IMPROVED MLSA vs Traditional Features: Real Dataset Validation
# ======================================================================
#
# Using dataset: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
#
# ======================================================================
# IMPROVED MLSA VALIDATION EXPERIMENT
# Comparing Original vs Improved MLSA on 26-Speaker Dataset
# ======================================================================
#
# [Step 1] Loading Dataset...
# Loading dataset from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Found 1089 FLAC files
# Found 26 speakers
# Loaded 382 audio samples from 26 speakers
#   Loaded 382 samples from 26 speakers
#   Labels distribution: [15 15 15 15 11 15 15 15 15 15 15 15 15 15 15 15 15 15 15 13 15 15 15 14
#  15 14]
#
# [Step 2] Extracting Features...
#
#   Extracting MFCC features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   MFCC: shape=(382, 52), time=3.39s, failed=0
#
#   Extracting Mel features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   Mel: shape=(382, 160), time=2.19s, failed=0
#
#   Extracting MLSA_Original features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   MLSA_Original: shape=(382, 15), time=716.75s, failed=0
#
#   Extracting MLSA_Improved features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   MLSA_Improved: shape=(382, 23), time=678.89s, failed=0
#
#   Extracting MFCC+MLSA features...
#     Processed 50/382 samples...
#     Processed 100/382 samples...
#     Processed 150/382 samples...
#     Processed 200/382 samples...
#     Processed 250/382 samples...
#     Processed 300/382 samples...
#     Processed 350/382 samples...
#   MFCC+MLSA: shape=(382, 75), time=687.76s, failed=0
#
# [Step 3] Normalizing Features...
#
# [Step 4] Evaluating Feature Quality...
#
#   Evaluating MFCC...
#     Fisher Score:     0.7033
#     Silhouette Score: 0.0818
#     K-NN Accuracy:    81.93%
#     LDA Accuracy:     98.95%
#
#   Evaluating Mel...
#     Fisher Score:     1.2600
#     Silhouette Score: 0.0861
#     K-NN Accuracy:    79.58%
#     LDA Accuracy:     100.00%
#
#   Evaluating MLSA_Original...
#     Fisher Score:     1.4352
#     Silhouette Score: -0.0818
#     K-NN Accuracy:    34.04%
#     LDA Accuracy:     36.66%
#
#   Evaluating MLSA_Improved...
#     Fisher Score:     0.5876
#     Silhouette Score: -0.0854
#     K-NN Accuracy:    23.83%
#     LDA Accuracy:     40.33%
#
#   Evaluating MFCC+MLSA...
#     Fisher Score:     0.6660
#     Silhouette Score: 0.0732
#     K-NN Accuracy:    81.15%
#     LDA Accuracy:     98.95%
#
# [Step 5] MLSA Feature Importance Analysis...
#
#   Top 10 Most Important MLSA Features:
#     1. LLE_scale_4: 0.6535
#     2. LLE_scale_2: 0.5749
#     3. LLE_mean: 0.5711
#     4. zcr_variability: 0.5309
#     5. pitch_stability: 0.5251
#     6. LLE_max: 0.5070
#     7. LLE_std: 0.4899
#     8. LLE_range: 0.4237
#     9. LLE_scale_1: 0.3395
#     10. LLE_decay: 0.2838
#
# [Step 6] Creating Visualizations...
#   Saved visualization to: /scratch/project_2003370/yueyao/Model/scripts/outputs/mlsa_experiments/mlsa_improved_validation.png
#   Saved results to: /scratch/project_2003370/yueyao/Model/scripts/outputs/mlsa_experiments/mlsa_improved_results.json
#
# ======================================================================
# FINAL RESULTS SUMMARY
# ======================================================================
#
# --------------------------------------------------------------------------------
# Feature Type       Dim     Fisher   Silhouette       K-NN        LDA     Time
# --------------------------------------------------------------------------------
# MFCC                52     0.7033       0.0818     81.93%     98.95%     3.4s
# Mel                160     1.2600       0.0861     79.58%    100.00%     2.2s
# MLSA_Original       15     1.4352      -0.0818     34.04%     36.66%   716.8s
# MLSA_Improved       23     0.5876      -0.0854     23.83%     40.33%   678.9s
# MFCC+MLSA           75     0.6660       0.0732     81.15%     98.95%   687.8s
# --------------------------------------------------------------------------------
#
# ======================================================================
# CONCLUSIONS
# ======================================================================
#
# 1. MLSA Improvement:
#    - Original K-NN:  34.04%
#    - Improved K-NN:  23.83%
#    - Improvement:    -10.21%
#
# 2. Combined Performance:
#    - MFCC K-NN:      81.93%
#    - MFCC+MLSA:      81.15%
#    - Gain:           -0.78%
#
# 3. Key Improvements:
#    - Voiced segment selection → More stable LLE
#    - RQA features → Capture deterministic structure
#    - Correlation dimension → Attractor geometry
#    - Adaptive Theiler → Better neighbor selection
#
# 4. Verdict:
#    - MLSA Improved: NEEDS MORE TUNING
#    - Combined: REDUNDANT
#
#
# Total experiment time: 2112.24 seconds
#
# Experiment complete! Check outputs for visualizations.

# %%
# !python validate_mlsa_real_dataset.py
# Out:
# ======================================================================
# MLSA Comparison: Original vs Refined vs Hybrid
# ======================================================================
#
# Dataset: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
#
# ======================================================================
# MLSA COMPARISON EXPERIMENT
# Comparing Original vs Refined vs Hybrid MLSA
# ======================================================================
#
# [Step 1] Loading Dataset...
# Loading from: /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Found 1089 FLAC files
# Using 26 speakers
# Loaded 382 samples
#   382 samples, 26 speakers
#
# [Step 2] Extracting Features...
#
#   Extracting MFCC...
#     100/382...
#     200/382...
#     300/382...
#   MFCC: shape=(382, 52), time=3.8s
#
#   Extracting MLSA_Original...
#     100/382...
#     200/382...
#     300/382...
#   MLSA_Original: shape=(382, 13), time=737.8s
#
#   Extracting MLSA_Refined...
#     100/382...
#     200/382...
#     300/382...
#   MLSA_Refined: shape=(382, 14), time=897.9s
#
#   Extracting MLSA_Hybrid...
#     100/382...
#     200/382...
#     300/382...
#   MLSA_Hybrid: shape=(382, 16), time=742.3s
#
#   Extracting MFCC+Original...
#     100/382...
#     200/382...
#     300/382...
#   MFCC+Original: shape=(382, 65), time=746.0s
#
#   Extracting MFCC+Refined...
#     100/382...
#     200/382...
#     300/382...
#   MFCC+Refined: shape=(382, 66), time=902.8s
#
#   Extracting MFCC+Hybrid...
#     100/382...
#     200/382...
#     300/382...
#   MFCC+Hybrid: shape=(382, 68), time=753.8s
#
# [Step 3] Normalizing...
#
# [Step 4] Evaluating...
#
#   MFCC:
#     Fisher=0.7033, Silhouette=0.0818
#     K-NN=81.93%, LDA=98.95%
#
#   MLSA_Original:
#     Fisher=0.8592, Silhouette=-0.1656
#     K-NN=24.60%, LDA=29.60%
#
#   MLSA_Refined:
#     Fisher=1.5523, Silhouette=-0.0543
#     K-NN=40.86%, LDA=41.37%
#
#   MLSA_Hybrid:
#     Fisher=0.8403, Silhouette=-0.0857
#     K-NN=32.47%, LDA=42.14%
#
#   MFCC+Original:
#     Fisher=0.7323, Silhouette=0.0811
#     K-NN=79.06%, LDA=97.64%
#
#   MFCC+Refined:
#     Fisher=0.8326, Silhouette=0.1002
#     K-NN=86.38%, LDA=99.47%
#
#   MFCC+Hybrid:
#     Fisher=0.7336, Silhouette=0.0858
#     K-NN=82.98%, LDA=97.90%
#
# [Step 5] Creating Visualizations...
#   Saved to: /scratch/project_2003370/yueyao/Model/scripts/outputs/mlsa_experiments/mlsa_comparison_results.png
#   Saved to: /scratch/project_2003370/yueyao/Model/scripts/outputs/mlsa_experiments/mlsa_comparison_results.json
#
# ================================================================================
# FINAL RESULTS
# ================================================================================
#
# --------------------------------------------------------------------------------
# Method                 Dim     Fisher   Silhouette       K-NN        LDA
# --------------------------------------------------------------------------------
# MFCC                    52     0.7033       0.0818     81.93%     98.95%
# MLSA_Original           13     0.8592      -0.1656     24.60%     29.60%
# MLSA_Refined            14     1.5523      -0.0543     40.86%     41.37%
# MLSA_Hybrid             16     0.8403      -0.0857     32.47%     42.14%
# MFCC+Original           65     0.7323       0.0811     79.06%     97.64%
# MFCC+Refined            66     0.8326       0.1002     86.38%     99.47%
# MFCC+Hybrid             68     0.7336       0.0858     82.98%     97.90%
# --------------------------------------------------------------------------------
#
# *** BEST MLSA VARIANT: MLSA_Refined (Fisher=1.5523) ***
# *** BEST COMBINED: MFCC+Refined (K-NN=86.38%) ***
#
# ================================================================================
# IMPROVEMENT ANALYSIS
# ================================================================================
#
# MLSA_Refined vs Original:
#   Fisher: +0.6931
#   K-NN:   +16.26%
#
# MLSA_Hybrid vs Original:
#   Fisher: -0.0189
#   K-NN:   +7.87%
#
# Total time: 4802.8s
#
# Experiment complete!
