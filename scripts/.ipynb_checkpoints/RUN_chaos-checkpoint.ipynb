# %%
# !python train_chaotic.py \
    --system lorenz \
    --epochs 10 \
    --no_save_models \
    --no_analyze_dynamics
# Out:
# Error importing modules: No module named 'experiments.chaotic_experiment'
# Please ensure all project modules are installed and accessible.
