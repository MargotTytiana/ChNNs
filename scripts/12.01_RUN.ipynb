# %%
# !python run_experiment1.py --all
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# ...

# %%
# !python run_experiment2_simple.py
# Out:
# [2025-12-01 14:27:28] [INFO] Setting global random seed to: 42
# [2025-12-01 14:27:28] [INFO] Python random seed set
# [2025-12-01 14:27:28] [INFO] PYTHONHASHSEED set to: 42
# [2025-12-01 14:27:28] [INFO] NumPy random seed set
# [2025-12-01 14:27:28] [INFO] PyTorch CUDA seeds set
# [2025-12-01 14:27:28] [INFO] PyTorch strict reproducibility mode enabled
# [2025-12-01 14:27:28] [INFO] PyTorch seeds set
# [2025-12-01 14:27:28] [WARNING] TensorFlow not available - skipping TensorFlow seed
# [2025-12-01 14:27:28] [INFO] Environment information collected
# [2025-12-01 14:27:28] [INFO] Configuring deterministic operations
# [2025-12-01 14:27:28] [INFO] PyTorch deterministic operations configured
# [2025-12-01 14:27:28] [INFO] Starting reproducibility verification
# [2025-12-01 14:27:28] [INFO] Setting global random seed to: 42
# [2025-12-01 14:27:28] [INFO] Python random seed set
# [2025-12-01 14:27:28] [INFO] PYTHONHASHSEED set to: 42
# [2025-12-01 14:27:28] [INFO] NumPy random seed set
# ...

# %%
# !python run_experiment3_fewshot.py --all
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# ...

# %%
# !python run_experiment4_efficiency.py --all
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# ...

# %%
# !python run_chaotic_experiments.py --all
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# ...

# %%
# !python inspect_checkpoint.py outputs/experiment1_comparison/chaotic_hybrid/exp1_chaotic_hybrid/checkpoints/exp_20251130_185504/checkpoint_epoch_0000_20251201_195739.pkl
# Out:
# ...
# Inspecting: outputs/experiment1_comparison/chaotic_hybrid/exp1_chaotic_hybrid/checkpoints/exp_20251130_185504/checkpoint_epoch_0000_20251201_195739.pkl
# ...
# Loaded with pickle
#
# Top-level keys: ['epoch', 'timestamp', 'metrics', 'additional_info', 'model', 'framework']
# Saved at epoch: 0

# %%
# !python run_experiment5_visualization.py --model mel_mlp
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# ...

# %%
# !python run_experiment5_visualization.py --model mfcc_mlp
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# ...

# %%
# !python run_chaotic_experiments.py --exp 4,5
# Out:
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# ...

# %%
# !python train_chaotic.py \
    --system lorenz \
    --epochs 20\
    --save_models \
    --model_types full_chaotic \
    --data_dir /scratch/project_2003370/yueyao/dataset/mini_librispeech/LibriSpeech/dev-clean-2
# Out:
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# span=(0.0, 10.0), dt=0.05: expected 201, got 201
# span=(0.0, 10.0), dt=0.01: expected 1001, got 1001
# === Debug Complete ===
#
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# span=(0.0, 10.0), dt=0.1: expected 101, got 101
# ...

# %%
# !python run_training.py --config /scratch/project_2003370/yueyao/Model/experiments/configs/chaotic_config.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: plda
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: True
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# !python run_training.py --config /scratch/project_2003370/yueyao/Model/experiments/configs/chaotic_config.yaml
# Out:
# ...
# C-HiLAP: Chaotic Hierarchical Attractor Propagation
# Speaker Recognition with Chaos Theory
# ...
#
#
# ...
# CONFIGURATION SUMMARY
# ...
# Model type: full_chaotic
# Chaotic system: lorenz
# Num speakers: 251
# Batch size: 32
# Epochs: 100
# Classifier: plda
# ------------------------------------------------------------
# Loss functions enabled:
#   - Stability: True
#   - Sync: False
#   - Adversarial: True
# ...
#
#
# ----------------------------------------------------------------------
# Initializing experiment...
# ----------------------------------------------------------------------
#
# Fallback import setup: added /scratch/project_2003370/yueyao/Model to path
#
# === Integration Parameter Debug ===
# span=(0.0, 1.0), dt=0.1: expected 11, got 11
# span=(0.0, 1.0), dt=0.05: expected 21, got 21
# span=(0.0, 1.0), dt=0.01: expected 101, got 101
# span=(0.0, 5.0), dt=0.1: expected 51, got 51
# span=(0.0, 5.0), dt=0.05: expected 101, got 101
# span=(0.0, 5.0), dt=0.01: expected 501, got 501
# ...

# %%
# !python diagnose_bifurcation_full.py
# Out:
# ...
#  BIFURCATION CONTROL COMPREHENSIVE DIAGNOSTIC
# ...
#
# Project Root: /scratch/project_2003370/yueyao/Model
# Config Path: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/chaotic_config.yaml
#
# ...
#  DIAGNOSTIC 1: YAML Configuration Structure
# ...
#   [✗] Config file exists: FAIL
#       Not found: /scratch/project_2003370/yueyao/Model/experiments/configs/4.3_bifurcation_control/chaotic_config.yaml
#
# ...
#  DIAGNOSTIC 2: chaotic_experiment.py Analysis
# ...
#   [✗] File exists: FAIL
#
# ...
#  DIAGNOSTIC 3: chaotic_network.py Analysis
# ...
#   [✗] File exists: FAIL
#
# ...
#  DIAGNOSTIC 4: Runtime Test
# ...
#   [✓] PyTorch available: OK
#   [✗] Import ChaoticSpeakerRecognitionNetwork: FAIL
#       No module named 'chaotic_network'
#
# ...
#  DIAGNOSTIC 5: RECOMMENDED FIX
# ...
#
#   FILE TO MODIFY: chaotic_experiment.py
#   LOCATION: _create_model() method, around line 173-203
#
#   FIND THIS CODE:
#   ---------------
#   model = ChaoticSpeakerRecognitionNetwork(
# ...
